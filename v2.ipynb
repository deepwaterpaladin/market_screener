# %%
from screener.AsyncScreener2 import AsyncScreener2
path = './data/test_data.json'

# %%
screener2 = AsyncScreener2(ticker_path=path)

# %%
await screener2.run_async(batch_size=100)
# Out:
# Screening 100 stocks...
#
# Issue with AMZN
# Issue with LRCX
# Issue with ADP
# 100 stocks remaining after screening

# %%
screener2.results
# Out:
# {'MSFT': {'TBV Ratio': 22.739038236027167,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 38.508221725515114,
#   'isAdded': False},
#  'AAPL': {'TBV Ratio': 43.37479145093811,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 27.790811789370586,
#   'isAdded': False},
#  'GOOG': {'TBV Ratio': 6.9410565699225995,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 23.907916525509858,
#   'isAdded': False},
#  'AMZN': {'TBV Ratio': int,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 0,
#   'isAdded': False},
#  'NVDA': {'TBV Ratio': 41.2005636285,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 51.82742943548387,
#   'isAdded': False},
#  'META': {'TBV Ratio': 6.916577137386348,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 23.302804235510767,
#   'isAdded': False},
#  'TSLA': {'TBV Ratio': 12.483388521319913,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 52.58187345823055,
#   'isAdded': False},
#  'PLUS': {'TBV Ratio': 2.9351217993520873,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 17.649442889718078,
#   'isAdded': False},
#  'AVGO': {'TBV Ratio': -14.83679670277395,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 24.793317710552476,
#   'isAdded': False},
#  'V': {'TBV Ratio': -87.70791624771626,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 27.25734350576044,
#   'isAdded': False},
#  'JPM': {'TBV Ratio': 1.8970077837697146,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 10.087501210849208,
#   'isAdded': False},
#  'UNH': {'TBV Ratio': -24.419661119129852,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 21.829416022519105,
#   'isAdded': False},
#  'WMT': {'TBV Ratio': 7.122884995937215,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 28.68165502398556,
#   'isAdded': False},
#  'MA': {'TBV Ratio': -32.44624385646172,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 35.96475569450647,
#   'isAdded': False},
#  'XOM': {'TBV Ratio': 1.9061013089424008,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 11.250179394612609,
#   'isAdded': False},
#  'JNJ': {'TBV Ratio': -192.59081459994914,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 10.732665938042274,
#   'isAdded': False},
#  'PG': {'TBV Ratio': 39.214933020092076,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 27.033239330600175,
#   'isAdded': False},
#  'HD': {'TBV Ratio': -32.254179904246456,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 23.465911642342995,
#   'isAdded': False},
#  'MRK': {'TBV Ratio': -175.83200258399646,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 757.7636712328766,
#   'isAdded': False},
#  'ORCL': {'TBV Ratio': -6.06837689424013,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 30.72220884685201,
#   'isAdded': False},
#  'COST': {'TBV Ratio': 10.038544693311808,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 38.39280665924984,
#   'isAdded': False},
#  'ABBV': {'TBV Ratio': -3.5350419322672657,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 56.34113921447666,
#   'isAdded': False},
#  'CVX': {'TBV Ratio': 1.7771262093925075,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 13.073923908465533,
#   'isAdded': False},
#  'CRM': {'TBV Ratio': 47.630768958773245,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 66.1947920696325,
#   'isAdded': False},
#  'ADBE': {'TBV Ratio': 106.62811045723963,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 51.56573139277819,
#   'isAdded': False},
#  'AMD': {'TBV Ratio': 23.173248269643075,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 278.59454332552696,
#   'isAdded': False},
#  'BAC': {'TBV Ratio': 1.2142524963502466,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 10.19509568168961,
#   'isAdded': False},
#  'KO': {'TBV Ratio': -44.3591137062657,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 23.77771047227926,
#   'isAdded': False},
#  'NFLX': {'TBV Ratio': -19.421597095128313,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 39.75452774136047,
#   'isAdded': False},
#  'PEP': {'TBV Ratio': -805.8615177647384,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 25.7548864888693,
#   'isAdded': False},
#  'ACN': {'TBV Ratio': 18.756173287393715,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 29.712627339221665,
#   'isAdded': False},
#  'TMO': {'TBV Ratio': -14.795272964261635,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 34.17596997497915,
#   'isAdded': False},
#  'MCD': {'TBV Ratio': -27.85940919847538,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 25.48526697997355,
#   'isAdded': False},
#  'CSCO': {'TBV Ratio': 53.30109249472063,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 16.903541584079917,
#   'isAdded': False},
#  'LIN': {'TBV Ratio': 103.08736532650792,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 32.34472102113244,
#   'isAdded': False},
#  'ABT': {'TBV Ratio': 30.241875886085268,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 33.46528044731784,
#   'isAdded': False},
#  'TMUS': {'TBV Ratio': -4.05624071466226,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 22.84604304863052,
#   'isAdded': False},
#  'BABA': {'TBV Ratio': 1.644226273133728,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 16.72600371239486,
#   'isAdded': False},
#  'DHR': {'TBV Ratio': -19.22178587705168,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 35.76446473551638,
#   'isAdded': False},
#  'DIS': {'TBV Ratio': 6.474366369391783,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 62.939422259983,
#   'isAdded': False},
#  'INTC': {'TBV Ratio': 2.7067879411139075,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 124.65808170515098,
#   'isAdded': False},
#  'INTU': {'TBV Ratio': -49.07430035347515,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 60.313632550335576,
#   'isAdded': False},
#  'CMCSA': {'TBV Ratio': -2.3808543428624698,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 11.746146347803483,
#   'isAdded': False},
#  'WFC': {'TBV Ratio': 1.1806589880331648,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 9.48375958625013,
#   'isAdded': True},
#  'VZ': {'TBV Ratio': -1.6577009021888982,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 13.669252626140866,
#   'isAdded': False},
#  'AMGN': {'TBV Ratio': -3.4213486389672165,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 22.940404942682743,
#   'isAdded': False},
#  'IBM': {'TBV Ratio': -3.066365870538974,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 19.86516231304319,
#   'isAdded': False},
#  'CAT': {'TBV Ratio': 11.07542381331205,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 14.607557039187228,
#   'isAdded': False},
#  'PDD': {'TBV Ratio': 7.47562820169863,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 23.31619396971051,
#   'isAdded': False},
#  'QCOM': {'TBV Ratio': 12.942011331124176,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 17.056182245575222,
#   'isAdded': False},
#  'NOW': {'TBV Ratio': 23.36315391674144,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 83.31643508376662,
#   'isAdded': False},
#  'PFE': {'TBV Ratio': -3.7437946768566213,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 76.66916941953751,
#   'isAdded': False},
#  'NKE': {'TBV Ratio': 10.42643530518724,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 25.48257372573684,
#   'isAdded': False},
#  'UNP': {'TBV Ratio': 10.707864891932887,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 23.456921774572816,
#   'isAdded': False},
#  'GE': {'TBV Ratio': 11.668348420908897,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 11.691731884822278,
#   'isAdded': False},
#  'AXP': {'TBV Ratio': 5.711585365850075,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 16.44314545020301,
#   'isAdded': False},
#  'BX': {'TBV Ratio': 6.060515281456494,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 69.64661825471644,
#   'isAdded': False},
#  'UBER': {'TBV Ratio': 40.352553786224995,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 66.42026076841547,
#   'isAdded': False},
#  'TXN': {'TBV Ratio': 12.571286549562878,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 23.775373271889404,
#   'isAdded': False},
#  'SPGI': {'TBV Ratio': -9.913879559552523,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 53.41263061690784,
#   'isAdded': False},
#  'PM': {'TBV Ratio': -4.045890991760666,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 18.688360424932803,
#   'isAdded': False},
#  'MS': {'TBV Ratio': 1.9917475728150136,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 16.706393749312205,
#   'isAdded': False},
#  'AMAT': {'TBV Ratio': 8.931688712069286,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 16.05385064177363,
#   'isAdded': False},
#  'ISRG': {'TBV Ratio': 9.545744970503376,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 65.8959021134594,
#   'isAdded': False},
#  'RTX': {'TBV Ratio': -4.338901385107882,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 37.55356494522692,
#   'isAdded': False},
#  'COP': {'TBV Ratio': 2.832930964305282,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 12.7410792178516,
#   'isAdded': False},
#  'SYK': {'TBV Ratio': -91.45214484750691,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 35.91627677725118,
#   'isAdded': False},
#  'BA': {'TBV Ratio': -5.759906182762293,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': -71.0656291629163,
#   'isAdded': False},
#  'HON': {'TBV Ratio': -28.732740237639586,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 24.57365323435843,
#   'isAdded': False},
#  'BKNG': {'TBV Ratio': -17.84721297553315,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 29.889608486826766,
#   'isAdded': False},
#  'T': {'TBV Ratio': -1.4887038707297013,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 8.367859722222224,
#   'isAdded': True},
#  'GS': {'TBV Ratio': 1.193287188563602,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 15.438047909816813,
#   'isAdded': False},
#  'LOW': {'TBV Ratio': -8.487918936877076,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 16.53419363189231,
#   'isAdded': False},
#  'UPS': {'TBV Ratio': 14.781719382542864,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 20.134253130590338,
#   'isAdded': False},
#  'MDT': {'TBV Ratio': -27.926878928205,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 28.80054352557127,
#   'isAdded': False},
#  'ELV': {'TBV Ratio': 29.158847703924753,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 18.580424920661432,
#   'isAdded': False},
#  'BLK': {'TBV Ratio': 16.254238613561732,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 22.032735656924753,
#   'isAdded': False},
#  'NEE': {'TBV Ratio': 2.4137553005767924,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 16.835200273597813,
#   'isAdded': False},
#  'SCHW': {'TBV Ratio': 6.048643177314951,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 24.766370633510952,
#   'isAdded': False},
#  'TJX': {'TBV Ratio': 15.741155092251384,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 24.9768573983013,
#   'isAdded': False},
#  'DE': {'TBV Ratio': 6.376975019266104,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 10.571626991933897,
#   'isAdded': False},
#  'LRCX': {'TBV Ratio': int,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 36.41214479336805,
#   'isAdded': False},
#  'SBUX': {'TBV Ratio': -9.226765666753149,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 25.33831591708086,
#   'isAdded': False},
#  'ETN': {'TBV Ratio': -96.11126205018883,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 29.8667688004972,
#   'isAdded': False},
#  'SFE': {'TBV Ratio': 0.6332522522522522,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': -1.2873809523809525,
#   'isAdded': True},
#  'PANW': {'TBV Ratio': -50.7349524778039,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 172.3626836479418,
#   'isAdded': False},
#  'VRTX': {'TBV Ratio': 6.6989652131884245,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 28.968823350646478,
#   'isAdded': False},
#  'PGR': {'TBV Ratio': 4.646712686789869,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 23.87322468224682,
#   'isAdded': False},
#  'SHOP': {'TBV Ratio': 11.59501743851708,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 756.3113647431819,
#   'isAdded': False},
#  'C': {'TBV Ratio': 0.54632284903041,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 10.75903164282618,
#   'isAdded': True},
#  'LMT': {'TBV Ratio': -18.368842617318027,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 16.393926589595377,
#   'isAdded': False},
#  'ADP': {'TBV Ratio': int,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 25.784257729211085,
#   'isAdded': False},
#  'REGN': {'TBV Ratio': 3.758388698385049,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 23.703344546742212,
#   'isAdded': False},
#  'CI': {'TBV Ratio': -3.0588425637465986,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 17.042207474825716,
#   'isAdded': False},
#  'MMC': {'TBV Ratio': -12.494751035264548,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 24.91964323748669,
#   'isAdded': False},
#  'CVS': {'TBV Ratio': -2.3128242535016192,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 12.160067114093959,
#   'isAdded': False},
#  'AMWL': {'TBV Ratio': 1.176709717673751,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': -0.627318018437002,
#   'isAdded': False},
#  'LX': {'TBV Ratio': 0.24340717477421164,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 2.0123950119070235,
#   'isAdded': True},
#  'KNDI': {'TBV Ratio': 0.6119348954164319,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': 30929.201233875487,
#   'isAdded': True},
#  'EHTH': {'TBV Ratio': 0.8971671773859253,
#   'EnterpriseValue/FreeCashFlow Ratio': int,
#   'NCAV Ratio': int,
#   'P/E Ratio': -8.658804848656695,
#   'isAdded': True}}
