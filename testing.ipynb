# %%
from screenerV3.alpha_module import AlphaModule
from time import sleep
import requests
service_account = './screener/service_account.json'
v1_path = './data/cleaned_tickers.json'
test_path = './data/test_data.json'

# %%
a = AlphaModule(v1_path, sheet_path = service_account)

# %%
v = await a.run_async()
# Out:
# Sleeping for 55 seconds to avoid hitting API limit
# removing for: BL
# removing for: Market Cap
# removing for: BL
# removing for: BL
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: BL
# removing for: Market Cap
# removing for: BL
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: Market Cap
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: Market Cap
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: Market Cap
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: Market Cap
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: Market Cap
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# removing for: BL
# Phase 1 complete.
# 292 stocks removed
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# Sleeping for 55 seconds to avoid hitting API limit
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# Sleeping for 55 seconds to avoid hitting API limit
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# Sleeping for 55 seconds to avoid hitting API limit
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# Sleeping for 55 seconds to avoid hitting API limit
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# Sleeping for 55 seconds to avoid hitting API limit
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# Sleeping for 55 seconds to avoid hitting API limit
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# ...
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# Sleeping for 55 seconds to avoid hitting API limit
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# Sleeping for 55 seconds to avoid hitting API limit
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# removing for: AVG YIELD
# Phase 2 complete.
# 14939 stocks removed
# Sleeping for 55 seconds to avoid hitting API limit
# Sleeping for 55 seconds to avoid hitting API limit
# Sleeping for 55 seconds to avoid hitting API limit
# Sleeping for 55 seconds to avoid hitting API limit
# Sleeping for 55 seconds to avoid hitting API limit
# Sleeping for 55 seconds to avoid hitting API limit
# Phase 3 complete.
# 1287 stocks removed
# 18243 requests sent

# %%
v
# Out:
# {'3765.T': {'Name': 'GungHo Online Entertainment, Inc.',
#   'Market Cap': 175576567452,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Electronic Gaming & Multimedia',
#   'Has Dividends or Buybacks': 60.0,
#   '5Y average yield > 10%': 11.53,
#   '5Y average': 20247600000.0,
#   'NCAV': 99101000000,
#   'NCAV Ratio': 1.8},
#  '4694.T': {'Name': 'BML, Inc.',
#   'Market Cap': 105023200422,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Medical - Diagnostics & Research',
#   'Has Dividends or Buybacks': 100.0,
#   '5Y average yield > 10%': 11.69,
#   '5Y average': 12272000000.0,
#   'NCAV': 66966000000,
#   'NCAV Ratio': 1.6},
#  '6371.T': {'Name': 'Tsubakimoto Chain Co.',
#   'Market Cap': 67971880232,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 146.0,
#   '5Y average yield > 10%': 22.64,
#   '5Y average': 15388600000.0,
#   'NCAV': 80986000000,
#   'NCAV Ratio': 0.8},
#  '3116.T': {'Name': 'Toyota Boshoku Corporation',
#   'Market Cap': 344173241376,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 86.0,
#   '5Y average yield > 10%': 15.96,
#   '5Y average': 54937000000.0,
#   'NCAV': 69088000000,
#   'NCAV Ratio': 5.0},
#  '6988.T': {'Name': 'Nitto Denko Corporation',
#   'Market Cap': 358919974170,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Chemicals - Specialty',
#   'Has Dividends or Buybacks': 56.0,
#   '5Y average yield > 10%': 22.93,
#   '5Y average': 82297600000.0,
#   'NCAV': 456966000000,
#   'NCAV Ratio': 0.8},
#  '1963.T': {'Name': 'JGC Holdings Corporation',
#   'Market Cap': 309106709412,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Engineering & Construction',
#   'Has Dividends or Buybacks': 40.0,
#   '5Y average yield > 10%': 12.18,
#   '5Y average': 37654800000.0,
#   'NCAV': 203102000000,
#   'NCAV Ratio': 1.5},
#  '3254.T': {'Name': 'Pressance Corporation',
#   'Market Cap': 137273565930,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Real Estate - Services',
#   'Has Dividends or Buybacks': 46.0,
#   '5Y average yield > 10%': 25.93,
#   '5Y average': 35598800000.0,
#   'NCAV': 159204000000,
#   'NCAV Ratio': 0.9},
#  '7296.T': {'Name': 'F.C.C. Co., Ltd.',
#   'Market Cap': 118949651647,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 76.0,
#   '5Y average yield > 10%': 10.89,
#   '5Y average': 12950600000.0,
#   'NCAV': 109954000000,
#   'NCAV Ratio': 1.1},
#  '3201.T': {'Name': 'The Japan Wool Textile Co., Ltd.',
#   'Market Cap': 92131680904,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Apparel - Manufacturers',
#   'Has Dividends or Buybacks': 40.0,
#   '5Y average yield > 10%': 10.47,
#   '5Y average': 9642600000.0,
#   'NCAV': 41180000000,
#   'NCAV Ratio': 2.2},
#  '7278.T': {'Name': 'EXEDY Corporation',
#   'Market Cap': 147918414200,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 120.0,
#   '5Y average yield > 10%': 10.74,
#   '5Y average': 15891000000.0,
#   'NCAV': 85426000000,
#   'NCAV Ratio': 1.7},
#  '4980.T': {'Name': 'Dexerials Corporation',
#   'Market Cap': 123864315575,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Hardware, Equipment & Parts',
#   'Has Dividends or Buybacks': 52.0,
#   '5Y average yield > 10%': 10.28,
#   '5Y average': 12735800000.0,
#   'NCAV': 18522000000,
#   'NCAV Ratio': 6.7},
#  '8066.T': {'Name': 'Mitani Corporation',
#   'Market Cap': 149271171896,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Conglomerates',
#   'Has Dividends or Buybacks': 46.0,
#   '5Y average yield > 10%': 10.2,
#   '5Y average': 15233000000.0,
#   'NCAV': 127340000000,
#   'NCAV Ratio': 1.2},
#  '9936.T': {'Name': 'Ohsho Food Service Corp.',
#   'Market Cap': 53732624570,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Restaurants',
#   'Has Dividends or Buybacks': 100.0,
#   '5Y average yield > 10%': 11.92,
#   '5Y average': 6403800000.0,
#   'NCAV': 17706000000,
#   'NCAV Ratio': 3.0},
#  '1662.T': {'Name': 'Japan Petroleum Exploration Co., Ltd.',
#   'Market Cap': 55040620840,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Oil & Gas Exploration & Production',
#   'Has Dividends or Buybacks': 50.0,
#   '5Y average yield > 10%': 63.83,
#   '5Y average': 35132200000.0,
#   'NCAV': 59197000000,
#   'NCAV Ratio': 0.9},
#  '7283.T': {'Name': 'Aisan Industry Co., Ltd.',
#   'Market Cap': 90616255900,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 64.0,
#   '5Y average yield > 10%': 11.93,
#   '5Y average': 10809800000.0,
#   'NCAV': 19657000000,
#   'NCAV Ratio': 4.6},
#  '4507.T': {'Name': 'Shionogi & Co., Ltd.',
#   'Market Cap': 605963887088,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Drug Manufacturers - Specialty & Generic',
#   'Has Dividends or Buybacks': 57.33,
#   '5Y average yield > 10%': 17.61,
#   '5Y average': 106693600000.0,
#   'NCAV': 610104000000,
#   'NCAV Ratio': 1.0},
#  '6789.T': {'Name': 'Roland DG Corporation',
#   'Market Cap': 10720,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Computer Hardware',
#   'Has Dividends or Buybacks': 809838020.0,
#   '5Y average yield > 10%': 17318630.6,
#   '5Y average': 1856557200.0,
#   'NCAV': 21612739000,
#   'NCAV Ratio': 0.0},
#  '4726.T': {'Name': 'SB Technology Corp.',
#   'Market Cap': 5890,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Information Technology Services',
#   'Has Dividends or Buybacks': 792079230.0,
#   '5Y average yield > 10%': 10342954.16,
#   '5Y average': 609200000.0,
#   'NCAV': 21895000000,
#   'NCAV Ratio': 0.0},
#  '8935.T': {'Name': 'FJ Next Holdings Co., Ltd.',
#   'Market Cap': 40597681844,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Real Estate - Services',
#   'Has Dividends or Buybacks': 48.0,
#   '5Y average yield > 10%': 15.07,
#   '5Y average': 6118800000.0,
#   'NCAV': 55664000000,
#   'NCAV Ratio': 0.7},
#  '2497.T': {'Name': 'UNITED, Inc.',
#   'Market Cap': 31129355178,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Software - Application',
#   'Has Dividends or Buybacks': 48.0,
#   '5Y average yield > 10%': 11.37,
#   '5Y average': 3540306600.0,
#   'NCAV': 20039451000,
#   'NCAV Ratio': 1.6},
#  '3932.T': {'Name': 'Akatsuki Inc.',
#   'Market Cap': 30454224768,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Electronic Gaming & Multimedia',
#   'Has Dividends or Buybacks': 80.0,
#   '5Y average yield > 10%': 16.04,
#   '5Y average': 4885800000.0,
#   'NCAV': 26573000000,
#   'NCAV Ratio': 1.1},
#  '7803.T': {'Name': 'Bushiroad Inc.',
#   'Market Cap': 26444338518,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Electronic Gaming & Multimedia',
#   'Has Dividends or Buybacks': 9.0,
#   '5Y average yield > 10%': 11.35,
#   '5Y average': 3001158400.0,
#   'NCAV': 13181295000,
#   'NCAV Ratio': 2.0},
#  '9845.T': {'Name': 'Parker Corporation',
#   'Market Cap': 19536612689,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Distribution',
#   'Has Dividends or Buybacks': 25.0,
#   '5Y average yield > 10%': 13.2,
#   '5Y average': 2578000000.0,
#   'NCAV': 22442000000,
#   'NCAV Ratio': 0.9},
#  '6932.T': {'Name': 'ENDO Lighting Corporation',
#   'Market Cap': 20051232836,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Furnishings, Fixtures & Appliances',
#   'Has Dividends or Buybacks': 40.0,
#   '5Y average yield > 10%': 13.57,
#   '5Y average': 2720000000.0,
#   'NCAV': 16703000000,
#   'NCAV Ratio': 1.2},
#  '6470.T': {'Name': 'Taiho Kogyo Co., Ltd.',
#   'Market Cap': 18265186784,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 20.0,
#   '5Y average yield > 10%': 12.02,
#   '5Y average': 2195600000.0,
#   'NCAV': 16331000000,
#   'NCAV Ratio': 1.1},
#  '9441.T': {'Name': 'Bell-Park Co.,Ltd.',
#   'Market Cap': 32805413960,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Specialty Retail',
#   'Has Dividends or Buybacks': 44.0,
#   '5Y average yield > 10%': 11.11,
#   '5Y average': 3645707000.0,
#   'NCAV': 26134652000,
#   'NCAV Ratio': 1.3},
#  '6482.T': {'Name': 'Yushin Precision Equipment Co., Ltd.',
#   'Market Cap': 22360904991,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 20.0,
#   '5Y average yield > 10%': 10.76,
#   '5Y average': 2406336800.0,
#   'NCAV': 19920037000,
#   'NCAV Ratio': 1.1},
#  '2120.T': {'Name': 'LIFULL Co., Ltd.',
#   'Market Cap': 18815239275,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Internet Content & Information',
#   'Has Dividends or Buybacks': 6.51,
#   '5Y average yield > 10%': 14.54,
#   '5Y average': 2736042600.0,
#   'NCAV': 4881000000,
#   'NCAV Ratio': 3.9},
#  '6137.T': {'Name': 'Koike Sanso Kogyo Co.,Ltd.',
#   'Market Cap': 24797382980,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 200.0,
#   '5Y average yield > 10%': 11.21,
#   '5Y average': 2779800000.0,
#   'NCAV': 10387000000,
#   'NCAV Ratio': 2.4},
#  '7229.T': {'Name': 'Yutaka Giken Co.,Ltd.',
#   'Market Cap': 27709845130,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 72.0,
#   '5Y average yield > 10%': 25.66,
#   '5Y average': 7110400000.0,
#   'NCAV': 58954000000,
#   'NCAV Ratio': 0.5},
#  '3843.T': {'Name': 'FreeBit Co., Ltd.',
#   'Market Cap': 24545660511,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Internet Content & Information',
#   'Has Dividends or Buybacks': 57.0,
#   '5Y average yield > 10%': 11.53,
#   '5Y average': 2829598600.0,
#   'NCAV': 8830816000,
#   'NCAV Ratio': 2.8},
#  '2491.T': {'Name': 'ValueCommerce Co., Ltd.',
#   'Market Cap': 24693361020,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Advertising Agencies',
#   'Has Dividends or Buybacks': 54.0,
#   '5Y average yield > 10%': 18.8,
#   '5Y average': 4643420200.0,
#   'NCAV': 10195000000,
#   'NCAV Ratio': 2.4},
#  '4832.T': {'Name': 'JFE Systems, Inc.',
#   'Market Cap': 45465575490,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Computer Hardware',
#   'Has Dividends or Buybacks': 102.0,
#   '5Y average yield > 10%': 10.76,
#   '5Y average': 4893628000.0,
#   'NCAV': 19986334000,
#   'NCAV Ratio': 2.3},
#  '1518.T': {'Name': 'Mitsui Matsushima Holdings Co., Ltd.',
#   'Market Cap': 59631902660,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Coal',
#   'Has Dividends or Buybacks': 100.0,
#   '5Y average yield > 10%': 19.82,
#   '5Y average': 11821800000.0,
#   'NCAV': 26064000000,
#   'NCAV Ratio': 2.3},
#  '7879.T': {'Name': 'Noda Corporation',
#   'Market Cap': 14371853652,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Construction Materials',
#   'Has Dividends or Buybacks': 45.0,
#   '5Y average yield > 10%': 20.74,
#   '5Y average': 2980774200.0,
#   'NCAV': 14592035000,
#   'NCAV Ratio': 1.0},
#  '3431.T': {'Name': 'Miyaji Engineering Group,Inc.',
#   'Market Cap': 28920247000,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Engineering & Construction',
#   'Has Dividends or Buybacks': 110.0,
#   '5Y average yield > 10%': 12.24,
#   '5Y average': 3538872000.0,
#   'NCAV': 22399000000,
#   'NCAV Ratio': 1.3},
#  '9906.T': {'Name': 'Fujii Sangyo Corporation',
#   'Market Cap': 20574878604,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 100.0,
#   '5Y average yield > 10%': 10.61,
#   '5Y average': 2183478000.0,
#   'NCAV': 22239520000,
#   'NCAV Ratio': 0.9},
#  '3157.T': {'Name': 'JUTEC Holdings Corporation',
#   'Market Cap': 15103509826,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Construction Materials',
#   'Has Dividends or Buybacks': 38.0,
#   '5Y average yield > 10%': 10.93,
#   '5Y average': 1651400000.0,
#   'NCAV': 4071000000,
#   'NCAV Ratio': 3.7},
#  '2790.T': {'Name': 'NAFCO Co., Ltd.',
#   'Market Cap': 67369364532,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Home Improvement',
#   'Has Dividends or Buybacks': 58.0,
#   '5Y average yield > 10%': 10.51,
#   '5Y average': 7083000000.0,
#   'NCAV': 23776000000,
#   'NCAV Ratio': 2.8},
#  '6463.T': {'Name': 'TPR Co., Ltd.',
#   'Market Cap': 76690140624,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 100.0,
#   '5Y average yield > 10%': 12.61,
#   '5Y average': 9671400000.0,
#   'NCAV': 38432000000,
#   'NCAV Ratio': 2.0},
#  '6357.T': {'Name': 'Sansei Technologies, Inc.',
#   'Market Cap': 26513579498,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 50.0,
#   '5Y average yield > 10%': 13.64,
#   '5Y average': 3615844600.0,
#   'NCAV': 10384794000,
#   'NCAV Ratio': 2.6},
#  '3040.T': {'Name': 'Soliton Systems K.K.',
#   'Market Cap': 20946937690,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Software - Infrastructure',
#   'Has Dividends or Buybacks': 26.0,
#   '5Y average yield > 10%': 10.11,
#   '5Y average': 2118000000.0,
#   'NCAV': 8695000000,
#   'NCAV Ratio': 2.4},
#  '1939.T': {'Name': 'Yondenko Corporation',
#   'Market Cap': 20356670043,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Engineering & Construction',
#   'Has Dividends or Buybacks': 50.0,
#   '5Y average yield > 10%': 19.43,
#   '5Y average': 3955200000.0,
#   'NCAV': 16608000000,
#   'NCAV Ratio': 1.2},
#  '7246.T': {'Name': 'Press Kogyo Co., Ltd.',
#   'Market Cap': 58614068183,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 28.0,
#   '5Y average yield > 10%': 11.22,
#   '5Y average': 6574000000.0,
#   'NCAV': 17721000000,
#   'NCAV Ratio': 3.3},
#  '2763.T': {'Name': 'FTGroup Co., Ltd.',
#   'Market Cap': 34044404533,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Communication Equipment',
#   'Has Dividends or Buybacks': 70.0,
#   '5Y average yield > 10%': 11.82,
#   '5Y average': 4023425600.0,
#   'NCAV': 19137000000,
#   'NCAV Ratio': 1.8},
#  '2915.T': {'Name': 'KENKO Mayonnaise Co.,Ltd.',
#   'Market Cap': 36839122510,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Packaged Foods',
#   'Has Dividends or Buybacks': 38.0,
#   '5Y average yield > 10%': 10.11,
#   '5Y average': 3726000000.0,
#   'NCAV': 9444000000,
#   'NCAV Ratio': 3.9},
#  '6035.T': {'Name': 'IR Japan Holdings, Ltd.',
#   'Market Cap': 16235722922,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Consulting Services',
#   'Has Dividends or Buybacks': 25.0,
#   '5Y average yield > 10%': 11.44,
#   '5Y average': 1858093600.0,
#   'NCAV': 3781640000,
#   'NCAV Ratio': 4.3},
#  '5363.T': {'Name': 'TYK Corporation',
#   'Market Cap': 18263933632,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Construction Materials',
#   'Has Dividends or Buybacks': 16.6,
#   '5Y average yield > 10%': 12.29,
#   '5Y average': 2244442800.0,
#   'NCAV': 23444304000,
#   'NCAV Ratio': 0.8},
#  '4659.T': {'Name': 'AJIS Co., Ltd.',
#   'Market Cap': 21182684946,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Specialty Business Services',
#   'Has Dividends or Buybacks': 85.0,
#   '5Y average yield > 10%': 12.0,
#   '5Y average': 2542144200.0,
#   'NCAV': 14514084000,
#   'NCAV Ratio': 1.5},
#  '6358.T': {'Name': 'Sakai Heavy Industries, Ltd.',
#   'Market Cap': 10335587568,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Agricultural - Machinery',
#   'Has Dividends or Buybacks': 107.5,
#   '5Y average yield > 10%': 17.79,
#   '5Y average': 1838195000.0,
#   'NCAV': 13775334000,
#   'NCAV Ratio': 0.8},
#  '8291.T': {'Name': 'Nissan Tokyo Sales Holdings Co., Ltd.',
#   'Market Cap': 30558997380,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Dealerships',
#   'Has Dividends or Buybacks': 24.0,
#   '5Y average yield > 10%': 12.04,
#   '5Y average': 3678400000.0,
#   'NCAV': 2507000000,
#   'NCAV Ratio': 12.2},
#  '8037.T': {'Name': 'Kamei Corporation',
#   'Market Cap': 67771460193,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Oil & Gas Refining & Marketing',
#   'Has Dividends or Buybacks': 56.0,
#   '5Y average yield > 10%': 12.34,
#   '5Y average': 8362200000.0,
#   'NCAV': 33718000000,
#   'NCAV Ratio': 2.0},
#  '9386.T': {'Name': 'Nippon Concept Corporation',
#   'Market Cap': 23713895250,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Oil & Gas Midstream',
#   'Has Dividends or Buybacks': 60.0,
#   '5Y average yield > 10%': 11.81,
#   '5Y average': 2799557000.0,
#   'NCAV': 6094936000,
#   'NCAV Ratio': 3.9},
#  '5121.T': {'Name': 'FUJIKURA COMPOSITES Inc.',
#   'Market Cap': 23193469208,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 60.0,
#   '5Y average yield > 10%': 10.97,
#   '5Y average': 2543338600.0,
#   'NCAV': 16088211000,
#   'NCAV Ratio': 1.4},
#  '4433.T': {'Name': 'HITO-Communications Holdings,Inc.',
#   'Market Cap': 15647755859,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Staffing & Employment Services',
#   'Has Dividends or Buybacks': 35.0,
#   '5Y average yield > 10%': 18.74,
#   '5Y average': 2931800000.0,
#   'NCAV': 5599000000,
#   'NCAV Ratio': 2.8},
#  '1972.T': {'Name': 'Sanko Metal Industrial Co., Ltd.',
#   'Market Cap': 15962353740,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Construction',
#   'Has Dividends or Buybacks': 190.0,
#   '5Y average yield > 10%': 11.19,
#   '5Y average': 1786000000.0,
#   'NCAV': 15458000000,
#   'NCAV Ratio': 1.0},
#  '4619.T': {'Name': 'Nihon Tokushu Toryo Co., Ltd.',
#   'Market Cap': 26246151029,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Chemicals - Specialty',
#   'Has Dividends or Buybacks': 52.0,
#   '5Y average yield > 10%': 11.58,
#   '5Y average': 3039400000.0,
#   'NCAV': 11039000000,
#   'NCAV Ratio': 2.4},
#  '1780.T': {'Name': 'Yamaura Corporation',
#   'Market Cap': 22220549236,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Engineering & Construction',
#   'Has Dividends or Buybacks': 10.0,
#   '5Y average yield > 10%': 11.24,
#   '5Y average': 2496944400.0,
#   'NCAV': 14943106000,
#   'NCAV Ratio': 1.5},
#  '8881.T': {'Name': 'NISSHIN GROUP HOLDINGS Company, Limited',
#   'Market Cap': 23794165992,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Real Estate - Services',
#   'Has Dividends or Buybacks': 46.0,
#   '5Y average yield > 10%': 10.15,
#   '5Y average': 2414204800.0,
#   'NCAV': 49227529000,
#   'NCAV Ratio': 0.5},
#  '3166.T': {'Name': 'Ochi Holdings Co., Ltd.',
#   'Market Cap': 18317445282,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Home Improvement',
#   'Has Dividends or Buybacks': 54.0,
#   '5Y average yield > 10%': 11.3,
#   '5Y average': 2069000000.0,
#   'NCAV': 1386000000,
#   'NCAV Ratio': 13.2},
#  '1866.T': {'Name': 'Kitano Construction Corp.',
#   'Market Cap': 22986278390,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Engineering & Construction',
#   'Has Dividends or Buybacks': 200.0,
#   '5Y average yield > 10%': 16.95,
#   '5Y average': 3895676600.0,
#   'NCAV': 11156000000,
#   'NCAV Ratio': 2.1},
#  '7539.T': {'Name': 'AINAVO HOLDINGS Co.,Ltd.',
#   'Market Cap': 7147614960,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Construction',
#   'Has Dividends or Buybacks': 22.0,
#   '5Y average yield > 10%': 20.27,
#   '5Y average': 1449060200.0,
#   'NCAV': 12014428000,
#   'NCAV Ratio': 0.6},
#  '1776.T': {'Name': 'Sumiken Mitsui Road Co.,Ltd.',
#   'Market Cap': 9590149548,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Engineering & Construction',
#   'Has Dividends or Buybacks': 80.0,
#   '5Y average yield > 10%': 12.15,
#   '5Y average': 1164800000.0,
#   'NCAV': 5823000000,
#   'NCAV Ratio': 1.6},
#  '4308.T': {'Name': 'J-Stream Inc.',
#   'Market Cap': 8230757878,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Entertainment',
#   'Has Dividends or Buybacks': 28.0,
#   '5Y average yield > 10%': 10.38,
#   '5Y average': 854348000.0,
#   'NCAV': 7761447000,
#   'NCAV Ratio': 1.1},
#  '7050.T': {'Name': 'Frontier International Inc.',
#   'Market Cap': 7110940200,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Advertising Agencies',
#   'Has Dividends or Buybacks': 78.0,
#   '5Y average yield > 10%': 14.61,
#   '5Y average': 1038840200.0,
#   'NCAV': 5867561000,
#   'NCAV Ratio': 1.2},
#  '8887.T': {'Name': 'Cumica Corporation',
#   'Market Cap': 4812059700,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Real Estate - Development',
#   'Has Dividends or Buybacks': 6.0,
#   '5Y average yield > 10%': 28.93,
#   '5Y average': 1391981200.0,
#   'NCAV': 5867901000,
#   'NCAV Ratio': 0.8},
#  '5906.T': {'Name': 'MK Seiko Co., Ltd.',
#   'Market Cap': 6266151556,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Consumer Electronics',
#   'Has Dividends or Buybacks': 16.0,
#   '5Y average yield > 10%': 21.28,
#   '5Y average': 1333539200.0,
#   'NCAV': 6354012000,
#   'NCAV Ratio': 1.0},
#  '6094.T': {'Name': 'FreakOut Holdings, inc.',
#   'Market Cap': 12660882504,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Advertising Agencies',
#   'Has Dividends or Buybacks': -1474000,
#   '5Y average yield > 10%': 10.34,
#   '5Y average': 1308972400.0,
#   'NCAV': 7294112000,
#   'NCAV Ratio': 1.7},
#  '2935.T': {'Name': 'Pickles Holdings Co.,Ltd.',
#   'Market Cap': 13145940710,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Packaged Foods',
#   'Has Dividends or Buybacks': 24.0,
#   '5Y average yield > 10%': 11.45,
#   '5Y average': 1505200000.0,
#   'NCAV': 3169000000,
#   'NCAV Ratio': 4.1},
#  '3948.T': {'Name': 'Hikari Business Form Co., Ltd.',
#   'Market Cap': 4333748850,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Specialty Business Services',
#   'Has Dividends or Buybacks': 73.0,
#   '5Y average yield > 10%': 19.72,
#   '5Y average': 854740200.0,
#   'NCAV': 3404966000,
#   'NCAV Ratio': 1.3},
#  '6149.T': {'Name': 'Odawara Engineering Co., Ltd.',
#   'Market Cap': 8708009128,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 100.0,
#   '5Y average yield > 10%': 13.1,
#   '5Y average': 1140652800.0,
#   'NCAV': 10149711000,
#   'NCAV Ratio': 0.9},
#  '9265.T': {'Name': 'Yamashita Health Care Holdings,Inc.',
#   'Market Cap': 6973109514,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Medical - Distribution',
#   'Has Dividends or Buybacks': 122.0,
#   '5Y average yield > 10%': 14.0,
#   '5Y average': 976121200.0,
#   'NCAV': 2888000000,
#   'NCAV Ratio': 2.4},
#  '3892.T': {'Name': 'Okayama Paper Industries Co., Ltd.',
#   'Market Cap': 6425376792,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Basic Materials',
#   'Has Dividends or Buybacks': 30.0,
#   '5Y average yield > 10%': 10.7,
#   '5Y average': 687283600.0,
#   'NCAV': 5805387000,
#   'NCAV Ratio': 1.1},
#  '6382.T': {'Name': 'Trinity Industrial Corporation',
#   'Market Cap': 15607351410,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 40.0,
#   '5Y average yield > 10%': 13.5,
#   '5Y average': 2107210400.0,
#   'NCAV': 16220956000,
#   'NCAV Ratio': 1.0},
#  '6874.T': {'Name': 'Kyoritsu Electric Corporation',
#   'Market Cap': 12836760970,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Hardware, Equipment & Parts',
#   'Has Dividends or Buybacks': 240.0,
#   '5Y average yield > 10%': 10.3,
#   '5Y average': 1322344000.0,
#   'NCAV': 9546113000,
#   'NCAV Ratio': 1.3},
#  '5644.T': {'Name': 'Metalart Corporation',
#   'Market Cap': 8812480820,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Manufacturing - Metal Fabrication',
#   'Has Dividends or Buybacks': 128.0,
#   '5Y average yield > 10%': 13.06,
#   '5Y average': 1150800000.0,
#   'NCAV': 7043000000,
#   'NCAV Ratio': 1.3},
#  '4395.T': {'Name': 'Accrete Inc.',
#   'Market Cap': 3549371798,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Telecommunications Services',
#   'Has Dividends or Buybacks': 10.0,
#   '5Y average yield > 10%': 10.71,
#   '5Y average': 380227200.0,
#   'NCAV': 878552000,
#   'NCAV Ratio': 4.0},
#  '7299.T': {'Name': 'Fuji Oozx Inc.',
#   'Market Cap': 12223495900,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 50.0,
#   '5Y average yield > 10%': 12.24,
#   '5Y average': 1496514999.8,
#   'NCAV': 11399096000,
#   'NCAV Ratio': 1.1},
#  '6518.T': {'Name': 'Sanso Electric Co.,Ltd.',
#   'Market Cap': 4251646996,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 50.0,
#   '5Y average yield > 10%': 15.02,
#   '5Y average': 638578200.0,
#   'NCAV': 4981863000,
#   'NCAV Ratio': 0.9},
#  '1850.T': {'Name': 'Nankai Tatsumura Construction Co., Ltd.',
#   'Market Cap': 8850089778,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Engineering & Construction',
#   'Has Dividends or Buybacks': 4.0,
#   '5Y average yield > 10%': 11.28,
#   '5Y average': 998600000.0,
#   'NCAV': 12605000000,
#   'NCAV Ratio': 0.7},
#  '9367.T': {'Name': 'Daito Koun Co.,Ltd.',
#   'Market Cap': 6158433710,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Marine Shipping',
#   'Has Dividends or Buybacks': 24.0,
#   '5Y average yield > 10%': 12.32,
#   '5Y average': 758541200.0,
#   'NCAV': 2970388000,
#   'NCAV Ratio': 2.1},
#  '5368.T': {'Name': 'Japan Insulation Co., Ltd.',
#   'Market Cap': 8204526672,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 74.0,
#   '5Y average yield > 10%': 13.91,
#   '5Y average': 1140932800.0,
#   'NCAV': 6879304000,
#   'NCAV Ratio': 1.2},
#  '4629.T': {'Name': 'Daishin Chemical Co.,Ltd.',
#   'Market Cap': 6341195322,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Chemicals - Specialty',
#   'Has Dividends or Buybacks': 80.0,
#   '5Y average yield > 10%': 12.85,
#   '5Y average': 815071800.0,
#   'NCAV': 10162767000,
#   'NCAV Ratio': 0.6},
#  '3374.T': {'Name': 'Naigai Tec Corporation',
#   'Market Cap': 8879609232,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Electrical Equipment & Parts',
#   'Has Dividends or Buybacks': 192.0,
#   '5Y average yield > 10%': 10.21,
#   '5Y average': 906650400.0,
#   'NCAV': 3203417000,
#   'NCAV Ratio': 2.8},
#  '7087.T': {'Name': 'WILLTEC Co.,Ltd.',
#   'Market Cap': 5369895720,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Semiconductors',
#   'Has Dividends or Buybacks': 40.0,
#   '5Y average yield > 10%': 12.1,
#   '5Y average': 649896400.0,
#   'NCAV': 4787000000,
#   'NCAV Ratio': 1.1},
#  '4224.T': {'Name': 'Lonseal Corporation',
#   'Market Cap': 6797608300,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Construction',
#   'Has Dividends or Buybacks': 70.0,
#   '5Y average yield > 10%': 10.44,
#   '5Y average': 709600000.0,
#   'NCAV': 10486000000,
#   'NCAV Ratio': 0.6},
#  '6336.T': {'Name': 'Ishii Hyoki Co., Ltd.',
#   'Market Cap': 4524705765,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 30.0,
#   '5Y average yield > 10%': 15.78,
#   '5Y average': 713792600.0,
#   'NCAV': 3732000000,
#   'NCAV Ratio': 1.2},
#  '6835.T': {'Name': 'Allied Telesis Holdings K.K.',
#   'Market Cap': 10314758086,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Communication Equipment',
#   'Has Dividends or Buybacks': 2.0,
#   '5Y average yield > 10%': 16.23,
#   '5Y average': 1673873600.0,
#   'NCAV': 3305788000,
#   'NCAV Ratio': 3.1},
#  '6034.T': {'Name': 'MRT Inc.',
#   'Market Cap': 4445184480,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Healthcare',
#   'Has Dividends or Buybacks': -290168000,
#   '5Y average yield > 10%': 18.57,
#   '5Y average': 825621800.0,
#   'NCAV': 3248398000,
#   'NCAV Ratio': 1.4},
#  '9782.T': {'Name': 'DMS Inc.',
#   'Market Cap': 8680196252,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Advertising Agencies',
#   'Has Dividends or Buybacks': 80.0,
#   '5Y average yield > 10%': 14.12,
#   '5Y average': 1225897400.0,
#   'NCAV': 8472118000,
#   'NCAV Ratio': 1.0},
#  '8085.T': {'Name': 'Narasaki Sangyo Co., Ltd.',
#   'Market Cap': 14945706626,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Distribution',
#   'Has Dividends or Buybacks': 210.0,
#   '5Y average yield > 10%': 11.47,
#   '5Y average': 1713600000.0,
#   'NCAV': 7536000000,
#   'NCAV Ratio': 2.0},
#  '4064.T': {'Name': 'Nippon Carbide Industries Co., Inc.',
#   'Market Cap': 16339172608,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Chemicals - Specialty',
#   'Has Dividends or Buybacks': 80.0,
#   '5Y average yield > 10%': 10.25,
#   '5Y average': 1674000000.0,
#   'NCAV': 10279000000,
#   'NCAV Ratio': 1.6},
#  '4262.T': {'Name': 'NIFTY Lifestyle Co., Ltd.',
#   'Market Cap': 5369130225,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Real Estate - Services',
#   'Has Dividends or Buybacks': 18.0,
#   '5Y average yield > 10%': 10.66,
#   '5Y average': 572369599.8,
#   'NCAV': 3248038000,
#   'NCAV Ratio': 1.7},
#  '5136.T': {'Name': 'tripla Co., Ltd.',
#   'Market Cap': 7485650664,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Technology',
#   'Has Dividends or Buybacks': -96000,
#   '5Y average yield > 10%': 10.79,
#   '5Y average': 807911000.0,
#   'NCAV': 604197000,
#   'NCAV Ratio': 12.4},
#  '1807.T': {'Name': 'Watanabe Sato Co., Ltd.',
#   'Market Cap': 10848389290,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Engineering & Construction',
#   'Has Dividends or Buybacks': 80.0,
#   '5Y average yield > 10%': 16.68,
#   '5Y average': 1810033800.0,
#   'NCAV': 6073382000,
#   'NCAV Ratio': 1.8},
#  '3943.T': {'Name': 'Ohishi Sangyo Co., Ltd.',
#   'Market Cap': 4031092407,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Packaging & Containers',
#   'Has Dividends or Buybacks': 32.0,
#   '5Y average yield > 10%': 20.08,
#   '5Y average': 809441200.0,
#   'NCAV': 7143000000,
#   'NCAV Ratio': 0.6},
#  '9799.T': {'Name': 'Asahi Intelligence Service Co., Ltd.',
#   'Market Cap': 6311163628,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Information Technology Services',
#   'Has Dividends or Buybacks': 28.0,
#   '5Y average yield > 10%': 13.13,
#   '5Y average': 828672000.0,
#   'NCAV': 6475705000,
#   'NCAV Ratio': 1.0},
#  '2876.T': {'Name': 'Delsole Corporation',
#   'Market Cap': 3953841312,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Packaged Foods',
#   'Has Dividends or Buybacks': 24.0,
#   '5Y average yield > 10%': 15.44,
#   '5Y average': 610665400.0,
#   'NCAV': 2492624000,
#   'NCAV Ratio': 1.6},
#  '4347.T': {'Name': 'Broadmedia Corporation',
#   'Market Cap': 11535551790,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Entertainment',
#   'Has Dividends or Buybacks': 80.0,
#   '5Y average yield > 10%': 10.64,
#   '5Y average': 1227599000.0,
#   'NCAV': 1620646000,
#   'NCAV Ratio': 7.1},
#  '8938.T': {'Name': 'GLOME Holdings,Inc.',
#   'Market Cap': 6090892953,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Real Estate - Services',
#   'Has Dividends or Buybacks': 2.0,
#   '5Y average yield > 10%': 23.21,
#   '5Y average': 1413400000.0,
#   'NCAV': 3431000000,
#   'NCAV Ratio': 1.8},
#  '7551.T': {'Name': 'Weds Co., Ltd.',
#   'Market Cap': 9991773680,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 27.0,
#   '5Y average yield > 10%': 11.2,
#   '5Y average': 1119414400.0,
#   'NCAV': 8842488000,
#   'NCAV Ratio': 1.1},
#  '6165.T': {'Name': 'Punch Industry Co., Ltd.',
#   'Market Cap': 10421931528,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Manufacturing - Tools & Accessories',
#   'Has Dividends or Buybacks': 19.62,
#   '5Y average yield > 10%': 12.48,
#   '5Y average': 1300293800.0,
#   'NCAV': 11495000000,
#   'NCAV Ratio': 0.9},
#  '7634.T': {'Name': 'Hoshi Iryo-Sanki Co., Ltd.',
#   'Market Cap': 13412336400,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Healthcare',
#   'Has Dividends or Buybacks': 70.0,
#   '5Y average yield > 10%': 11.03,
#   '5Y average': 1479096600.0,
#   'NCAV': 7264577000,
#   'NCAV Ratio': 1.8},
#  '2122.T': {'Name': 'Interspace Co.,Ltd.',
#   'Market Cap': 5931605295,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Advertising Agencies',
#   'Has Dividends or Buybacks': 60.0,
#   '5Y average yield > 10%': 11.48,
#   '5Y average': 680829400.0,
#   'NCAV': 4132526000,
#   'NCAV Ratio': 1.4},
#  '3623.T': {'Name': 'Billing System Corporation',
#   'Market Cap': 9434070000,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Software - Infrastructure',
#   'Has Dividends or Buybacks': 24.0,
#   '5Y average yield > 10%': 31.42,
#   '5Y average': 2963972400.0,
#   'NCAV': 2357122000,
#   'NCAV Ratio': 4.0},
#  '6989.T': {'Name': 'Hokuriku Electric Industry Co.,Ltd.',
#   'Market Cap': 11018793150,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Hardware, Equipment & Parts',
#   'Has Dividends or Buybacks': 120.0,
#   '5Y average yield > 10%': 16.09,
#   '5Y average': 1772600000.0,
#   'NCAV': 8232000000,
#   'NCAV Ratio': 1.3},
#  '9307.T': {'Name': 'Sugimura Warehouse Co., Ltd.',
#   'Market Cap': 10009012936,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Specialty Business Services',
#   'Has Dividends or Buybacks': 10.0,
#   '5Y average yield > 10%': 10.2,
#   '5Y average': 1021145000.0,
#   'NCAV': 2245044000,
#   'NCAV Ratio': 4.5},
#  '7417.T': {'Name': 'NANYO Corporation',
#   'Market Cap': 13163382812,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Distribution',
#   'Has Dividends or Buybacks': 40.0,
#   '5Y average yield > 10%': 11.09,
#   '5Y average': 1460000000.0,
#   'NCAV': 8432000000,
#   'NCAV Ratio': 1.6},
#  '7218.T': {'Name': 'Tanaka Seimitsu Kogyo Co., Ltd.',
#   'Market Cap': 9464048568,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 26.0,
#   '5Y average yield > 10%': 21.37,
#   '5Y average': 2022097600.0,
#   'NCAV': 9088030000,
#   'NCAV Ratio': 1.0},
#  '7427.T': {'Name': 'Echo Trading Co., Ltd.',
#   'Market Cap': 5813655075,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Packaged Foods',
#   'Has Dividends or Buybacks': 28.0,
#   '5Y average yield > 10%': 12.2,
#   '5Y average': 709225000.0,
#   'NCAV': 8415129000,
#   'NCAV Ratio': 0.7},
#  '7367.T': {'Name': 'CELM,Inc.',
#   'Market Cap': 4016049750,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Staffing & Employment Services',
#   'Has Dividends or Buybacks': 16.0,
#   '5Y average yield > 10%': 15.19,
#   '5Y average': 610070000.0,
#   'NCAV': 734458000,
#   'NCAV Ratio': 5.5},
#  '4317.T': {'Name': 'Ray Corporation',
#   'Market Cap': 6148228680,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Entertainment',
#   'Has Dividends or Buybacks': 20.0,
#   '5Y average yield > 10%': 11.44,
#   '5Y average': 703209200.0,
#   'NCAV': 3185644000,
#   'NCAV Ratio': 1.9},
#  '8023.T': {'Name': 'Daiko Denshi Tsushin, Ltd.',
#   'Market Cap': 10106660445,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Technology Distributors',
#   'Has Dividends or Buybacks': 59.0,
#   '5Y average yield > 10%': 17.53,
#   '5Y average': 1771489400.0,
#   'NCAV': 5991350000,
#   'NCAV Ratio': 1.7},
#  '2814.T': {'Name': 'Sato Foods Industries Co., Ltd.',
#   'Market Cap': 8048826605,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Packaged Foods',
#   'Has Dividends or Buybacks': 40.0,
#   '5Y average yield > 10%': 10.59,
#   '5Y average': 852771400.0,
#   'NCAV': 11014273001,
#   'NCAV Ratio': 0.7},
#  '7353.T': {'Name': 'KIYO Learning Co.,Ltd.',
#   'Market Cap': 2973487740,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Education & Training Services',
#   'Has Dividends or Buybacks': -143000,
#   '5Y average yield > 10%': 11.68,
#   '5Y average': 347325200.0,
#   'NCAV': 402557000,
#   'NCAV Ratio': 7.4},
#  '7614.T': {'Name': 'OM2 Network Co.,Ltd.',
#   'Market Cap': 9758411751,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Food Distribution',
#   'Has Dividends or Buybacks': 60.0,
#   '5Y average yield > 10%': 10.87,
#   '5Y average': 1060931800.0,
#   'NCAV': 10179756000,
#   'NCAV Ratio': 1.0},
#  '5958.T': {'Name': 'Sanyo Industries, Ltd.',
#   'Market Cap': 10021461250,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Construction',
#   'Has Dividends or Buybacks': 110.0,
#   '5Y average yield > 10%': 15.48,
#   '5Y average': 1551600000.0,
#   'NCAV': 11161000000,
#   'NCAV Ratio': 0.9},
#  '5590.T': {'Name': 'NETSTARS Co.,Ltd.',
#   'Market Cap': 19568649600,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Technology',
#   'Has Dividends or Buybacks': -2558130000,
#   '5Y average yield > 10%': 15.75,
#   '5Y average': 3082154000.0,
#   'NCAV': 5729057000,
#   'NCAV Ratio': 3.4},
#  '5284.T': {'Name': 'Yamau Holdings Co., Ltd.',
#   'Market Cap': 10567300579,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Construction Materials',
#   'Has Dividends or Buybacks': 158.0,
#   '5Y average yield > 10%': 12.6,
#   '5Y average': 1331578600.0,
#   'NCAV': 3347183000,
#   'NCAV Ratio': 3.2},
#  '9408.T': {'Name': 'BSN Media Holdings, Inc.',
#   'Market Cap': 9586058430,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Entertainment',
#   'Has Dividends or Buybacks': 14.0,
#   '5Y average yield > 10%': 11.18,
#   '5Y average': 1071708200.0,
#   'NCAV': 8170105000,
#   'NCAV Ratio': 1.2},
#  '6082.T': {'Name': 'RIDE ON EXPRESS HOLDINGS Co., Ltd.',
#   'Market Cap': 9885551934,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Restaurants',
#   'Has Dividends or Buybacks': 30.0,
#   '5Y average yield > 10%': 10.05,
#   '5Y average': 993623600.0,
#   'NCAV': 3594450000,
#   'NCAV Ratio': 2.8},
#  '1770.T': {'Name': 'Fujita Engineering Co., Ltd.',
#   'Market Cap': 12996686274,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Engineering & Construction',
#   'Has Dividends or Buybacks': 50.0,
#   '5Y average yield > 10%': 10.29,
#   '5Y average': 1337674200.0,
#   'NCAV': 8614081000,
#   'NCAV Ratio': 1.5},
#  '3665.T': {'Name': 'Enigmo Inc.',
#   'Market Cap': 13171303200,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Software - Infrastructure',
#   'Has Dividends or Buybacks': 20.0,
#   '5Y average yield > 10%': 13.13,
#   '5Y average': 1729219400.0,
#   'NCAV': 7409791000,
#   'NCAV Ratio': 1.8},
#  '3640.T': {'Name': 'Densan Co., Ltd.',
#   'Market Cap': 8243821787,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Semiconductors',
#   'Has Dividends or Buybacks': 37.0,
#   '5Y average yield > 10%': 10.59,
#   '5Y average': 873119600.0,
#   'NCAV': 909345000,
#   'NCAV Ratio': 9.1},
#  '2183.T': {'Name': 'Linical Co., Ltd.',
#   'Market Cap': 8899055784,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Biotechnology',
#   'Has Dividends or Buybacks': 31.0,
#   '5Y average yield > 10%': 12.36,
#   '5Y average': 1100059800.0,
#   'NCAV': 2179822000,
#   'NCAV Ratio': 4.1},
#  '6033.T': {'Name': 'Extreme Co.,Ltd.',
#   'Market Cap': 6299509920,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Electronic Gaming & Multimedia',
#   'Has Dividends or Buybacks': 52.0,
#   '5Y average yield > 10%': 12.32,
#   '5Y average': 776168200.0,
#   'NCAV': 3272707000,
#   'NCAV Ratio': 1.9},
#  '6049.T': {'Name': 'ItoKuro Inc.',
#   'Market Cap': 4767466620,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Internet Content & Information',
#   'Has Dividends or Buybacks': -300108000,
#   '5Y average yield > 10%': 12.95,
#   '5Y average': 617200000.0,
#   'NCAV': 7759027000,
#   'NCAV Ratio': 0.6},
#  '4767.T': {'Name': 'TOW Co.,Ltd.',
#   'Market Cap': 13729339624,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Advertising Agencies',
#   'Has Dividends or Buybacks': 15.0,
#   '5Y average yield > 10%': 12.24,
#   '5Y average': 1680445800.0,
#   'NCAV': 7543118000,
#   'NCAV Ratio': 1.8},
#  '7122.T': {'Name': 'The Kinki Sharyo Co., Ltd.',
#   'Market Cap': 10245255092,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 100.0,
#   '5Y average yield > 10%': 76.09,
#   '5Y average': 7795200000.0,
#   'NCAV': 14424000000,
#   'NCAV Ratio': 0.7},
#  '6384.T': {'Name': 'Showa Shinku Co., Ltd.',
#   'Market Cap': 8337931503,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 140.0,
#   '5Y average yield > 10%': 10.02,
#   '5Y average': 835473000.0,
#   'NCAV': 7215172000,
#   'NCAV Ratio': 1.2},
#  '2130.T': {'Name': 'Members Co., Ltd.',
#   'Market Cap': 12230966104,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Advertising Agencies',
#   'Has Dividends or Buybacks': 63.0,
#   '5Y average yield > 10%': 10.06,
#   '5Y average': 1230966400.0,
#   'NCAV': 1341997000,
#   'NCAV Ratio': 9.1},
#  '6445.T': {'Name': 'JANOME Corporation',
#   'Market Cap': 15694555416,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Furnishings, Fixtures & Appliances',
#   'Has Dividends or Buybacks': 50.0,
#   '5Y average yield > 10%': 12.99,
#   '5Y average': 2039200000.0,
#   'NCAV': 11793000000,
#   'NCAV Ratio': 1.3},
#  '5282.T': {'Name': 'GEOSTR Corporation',
#   'Market Cap': 9573179094,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Construction Materials',
#   'Has Dividends or Buybacks': 6.0,
#   '5Y average yield > 10%': 10.56,
#   '5Y average': 1010950200.0,
#   'NCAV': 12998259000,
#   'NCAV Ratio': 0.7},
#  '3020.T': {'Name': 'Applied Co., Ltd.',
#   'Market Cap': 7092797952,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Technology Distributors',
#   'Has Dividends or Buybacks': 120.0,
#   '5Y average yield > 10%': 17.7,
#   '5Y average': 1255400000.0,
#   'NCAV': 4941000000,
#   'NCAV Ratio': 1.4},
#  '8046.T': {'Name': 'Marufuji Sheet Piling Co.,Ltd.',
#   'Market Cap': 9856984608,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Steel',
#   'Has Dividends or Buybacks': 220.0,
#   '5Y average yield > 10%': 11.67,
#   '5Y average': 1150600000.0,
#   'NCAV': 19109000000,
#   'NCAV Ratio': 0.5},
#  '7254.T': {'Name': 'Univance Corporation',
#   'Market Cap': 10581659304,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Auto - Parts',
#   'Has Dividends or Buybacks': 12.0,
#   '5Y average yield > 10%': 10.18,
#   '5Y average': 1077165600.0,
#   'NCAV': 2380826000,
#   'NCAV Ratio': 4.4},
#  '1384.T': {'Name': 'Hokuryo Co., Ltd.',
#   'Market Cap': 8594260688,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Agricultural Farm Products',
#   'Has Dividends or Buybacks': 80.0,
#   '5Y average yield > 10%': 10.03,
#   '5Y average': 862114000.0,
#   'NCAV': 471000000,
#   'NCAV Ratio': 18.2},
#  '7371.T': {'Name': 'Zenken Corporation',
#   'Market Cap': 6365782500,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Specialty Business Services',
#   'Has Dividends or Buybacks': 26.0,
#   '5Y average yield > 10%': 12.94,
#   '5Y average': 823903800.0,
#   'NCAV': 2751673001,
#   'NCAV Ratio': 2.3},
#  '8917.T': {'Name': 'First Juken Co., Ltd.',
#   'Market Cap': 15609524812,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Residential Construction',
#   'Has Dividends or Buybacks': 43.0,
#   '5Y average yield > 10%': 11.76,
#   '5Y average': 1836107600.0,
#   'NCAV': 26161282000,
#   'NCAV Ratio': 0.6},
#  '3513.T': {'Name': 'Ichikawa Co., Ltd.',
#   'Market Cap': 7222163760,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Paper, Lumber & Forest Products',
#   'Has Dividends or Buybacks': 70.0,
#   '5Y average yield > 10%': 11.43,
#   '5Y average': 825178400.0,
#   'NCAV': 7410000000,
#   'NCAV Ratio': 1.0},
#  '9087.T': {'Name': 'Takase Corporation',
#   'Market Cap': 1256531100,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Specialty Business Services',
#   'Has Dividends or Buybacks': 140.0,
#   '5Y average yield > 10%': 24.97,
#   '5Y average': 313731800.0,
#   'NCAV': 485845000,
#   'NCAV Ratio': 2.6},
#  '5956.T': {'Name': 'Toso Company, Limited',
#   'Market Cap': 4679334920,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Furnishings, Fixtures & Appliances',
#   'Has Dividends or Buybacks': 10.0,
#   '5Y average yield > 10%': 14.68,
#   '5Y average': 686927000.0,
#   'NCAV': 8885234000,
#   'NCAV Ratio': 0.5},
#  '1795.T': {'Name': 'Masaru Corporation',
#   'Market Cap': 3428967060,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Engineering & Construction',
#   'Has Dividends or Buybacks': 250.0,
#   '5Y average yield > 10%': 11.98,
#   '5Y average': 410918600.0,
#   'NCAV': 2488751000,
#   'NCAV Ratio': 1.4},
#  '3059.T': {'Name': 'Hiraki Co.,Ltd.',
#   'Market Cap': 4443942591,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Consumer Cyclical',
#   'Has Dividends or Buybacks': 20.0,
#   '5Y average yield > 10%': 12.09,
#   '5Y average': 537145800.0,
#   'NCAV': 1829646000,
#   'NCAV Ratio': 2.4},
#  '6894.T': {'Name': 'Pulstec Industrial Co., Ltd.',
#   'Market Cap': 2353322920,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Electrical Equipment & Parts',
#   'Has Dividends or Buybacks': 120.0,
#   '5Y average yield > 10%': 10.63,
#   '5Y average': 250256600.0,
#   'NCAV': 2388171000,
#   'NCAV Ratio': 1.0},
#  '6307.T': {'Name': 'Sansei Co.,Ltd.',
#   'Market Cap': 3038783575,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Specialty Business Services',
#   'Has Dividends or Buybacks': 30.0,
#   '5Y average yield > 10%': 14.03,
#   '5Y average': 426403000.0,
#   'NCAV': 1330565000,
#   'NCAV Ratio': 2.3},
#  '7544.T': {'Name': 'Three F Co.,Ltd.',
#   'Market Cap': 3044907594,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Grocery Stores',
#   'Has Dividends or Buybacks': 10.0,
#   '5Y average yield > 10%': 10.24,
#   '5Y average': 311800000.0,
#   'NCAV': 3386000000,
#   'NCAV Ratio': 0.9},
#  '7131.T': {'Name': 'Nomura Corporation',
#   'Market Cap': 2492552465,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Packaging & Containers',
#   'Has Dividends or Buybacks': 107.0,
#   '5Y average yield > 10%': 11.37,
#   '5Y average': 283302400.0,
#   'NCAV': 808661000,
#   'NCAV Ratio': 3.1},
#  '6466.T': {'Name': 'TVE Co., Ltd.',
#   'Market Cap': 5434205600,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 50.0,
#   '5Y average yield > 10%': 10.61,
#   '5Y average': 576515000.0,
#   'NCAV': 6452518000,
#   'NCAV Ratio': 0.8},
#  '5936.T': {'Name': 'Toyo Shutter Co., Ltd.',
#   'Market Cap': 5117518096,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Construction',
#   'Has Dividends or Buybacks': 84.0,
#   '5Y average yield > 10%': 17.86,
#   '5Y average': 913878200.0,
#   'NCAV': 1559000000,
#   'NCAV Ratio': 3.3},
#  '6757.T': {'Name': 'OSG Corporation Co., Ltd.',
#   'Market Cap': 4103974950,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 80.0,
#   '5Y average yield > 10%': 10.72,
#   '5Y average': 439876800.0,
#   'NCAV': 716604000,
#   'NCAV Ratio': 5.7},
#  '2136.T': {'Name': 'HIP Corporation',
#   'Market Cap': 3989143865,
#   'HQ Location': 'JP',
#   'Exchange Location': 'Tokyo',
#   'Industry': 'Staffing & Employment Services',
#   'Has Dividends or Buybacks': 102.0,
#   '5Y average yield > 10%': 10.62,
#   '5Y average': 423584600.0,
#   'NCAV': 2110704000,
#   'NCAV Ratio': 1.9},
#  '3352.T': {'Name': 'Buffalo Co.,Ltd.',
# ...
#   'Industry': 'Aerospace & Defense',
#   'Has Dividends or Buybacks': -21027000,
#   '5Y average yield > 10%': 10.23,
#   '5Y average': 72007400.0,
#   'NCAV': 196714000,
#   'NCAV Ratio': 3.6},
#  'FLGT': {'Name': 'Fulgent Genetics, Inc.',
#   'Market Cap': 641078172,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Market',
#   'Industry': 'Medical - Diagnostics & Research',
#   'Has Dividends or Buybacks': -106367000,
#   '5Y average yield > 10%': 26.91,
#   '5Y average': 172518000.0,
#   'NCAV': 295713000,
#   'NCAV Ratio': 2.2},
#  'YALA': {'Name': 'Yalla Group Limited',
#   'Market Cap': 678164685,
#   'HQ Location': 'AE',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Software - Application',
#   'Has Dividends or Buybacks': -35527305,
#   '5Y average yield > 10%': 14.1,
#   '5Y average': 95652420.4,
#   'NCAV': 483822271,
#   'NCAV Ratio': 1.4},
#  'HSII': {'Name': 'Heidrick & Struggles International, Inc.',
#   'Market Cap': 764340588,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Select',
#   'Industry': 'Staffing & Employment Services',
#   'Has Dividends or Buybacks': -17506000,
#   '5Y average yield > 10%': 11.11,
#   '5Y average': 84882800.0,
#   'NCAV': 8026000,
#   'NCAV Ratio': 95.2},
#  'MED': {'Name': 'Medifast, Inc.',
#   'Market Cap': 210544950,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Personal Products & Services',
#   'Has Dividends or Buybacks': 6.6,
#   '5Y average yield > 10%': 56.32,
#   '5Y average': 118582200.0,
#   'NCAV': 136067000,
#   'NCAV Ratio': 1.5},
#  'SD': {'Name': 'SandRidge Energy, Inc.',
#   'Market Cap': 440601960,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Oil & Gas Exploration & Production',
#   'Has Dividends or Buybacks': -3436000,
#   '5Y average yield > 10%': 11.54,
#   '5Y average': 50833600.0,
#   'NCAV': 132398000,
#   'NCAV Ratio': 3.3},
#  'RGP': {'Name': 'Resources Connection, Inc.',
#   'Market Cap': 316638498,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Select',
#   'Industry': 'Consulting Services',
#   'Has Dividends or Buybacks': -42787000,
#   '5Y average yield > 10%': 14.54,
#   '5Y average': 46031400.0,
#   'NCAV': 148604000,
#   'NCAV Ratio': 2.1},
#  'MOV': {'Name': 'Movado Group, Inc.',
#   'Market Cap': 299027904,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Luxury Goods',
#   'Has Dividends or Buybacks': 1.4,
#   '5Y average yield > 10%': 21.71,
#   '5Y average': 64932400.0,
#   'NCAV': 271327000,
#   'NCAV Ratio': 1.1},
#  'CYD': {'Name': 'China Yuchai International Limited',
#   'Market Cap': 490708183,
#   'HQ Location': 'SG',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Industrial - Machinery',
#   'Has Dividends or Buybacks': 0.38,
#   '5Y average yield > 10%': 82.94,
#   '5Y average': 406988200.0,
#   'NCAV': 5581862000,
#   'NCAV Ratio': 0.1},
#  'TMST': {'Name': 'TimkenSteel Corporation',
#   'Market Cap': 895345800,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Steel',
#   'Has Dividends or Buybacks': -92100000,
#   '5Y average yield > 10%': 12.39,
#   '5Y average': 110940000.0,
#   'NCAV': 213100000,
#   'NCAV Ratio': 4.2},
#  'MRVI': {'Name': 'Maravai LifeSciences Holdings, Inc.',
#   'Market Cap': 2123838538,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Select',
#   'Industry': 'Biotechnology',
#   'Has Dividends or Buybacks': -1458229000,
#   '5Y average yield > 10%': 10.05,
#   '5Y average': 213404800.0,
#   'NCAV': 14168000,
#   'NCAV Ratio': 149.9},
#  'CCRN': {'Name': 'Cross Country Healthcare, Inc.',
#   'Market Cap': 445935434,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Select',
#   'Industry': 'Medical - Care Facilities',
#   'Has Dividends or Buybacks': -96628000,
#   '5Y average yield > 10%': 13.3,
#   '5Y average': 59312400.0,
#   'NCAV': 173937000,
#   'NCAV Ratio': 2.6},
#  'GRVY': {'Name': 'Gravity Co., Ltd.',
#   'Market Cap': 414015462,
#   'HQ Location': 'KR',
#   'Exchange Location': 'NASDAQ Global Market',
#   'Industry': 'Electronic Gaming & Multimedia',
#   'Has Dividends or Buybacks': 0.0,
#   '5Y average yield > 10%': 18466.78,
#   '5Y average': 76455324000.0,
#   'NCAV': 480613000000,
#   'NCAV Ratio': 0.0},
#  'USNA': {'Name': 'USANA Health Sciences, Inc.',
#   'Market Cap': 722463216,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Packaged Foods',
#   'Has Dividends or Buybacks': -421847000,
#   '5Y average yield > 10%': 14.22,
#   '5Y average': 102716800.0,
#   'NCAV': 299870000,
#   'NCAV Ratio': 2.4},
#  'KARO': {'Name': 'Karooooo Ltd.',
#   'Market Cap': 1263261940,
#   'HQ Location': 'SG',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Software - Application',
#   'Has Dividends or Buybacks': 1.08,
#   '5Y average yield > 10%': 27.69,
#   '5Y average': 349819800.0,
#   'NCAV': 195948000,
#   'NCAV Ratio': 6.4},
#  'TK': {'Name': 'Teekay Corporation',
#   'Market Cap': 851318793,
#   'HQ Location': 'BM',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Oil & Gas Midstream',
#   'Has Dividends or Buybacks': 1.0,
#   '5Y average yield > 10%': 49.08,
#   '5Y average': 417855600.0,
#   'NCAV': 795552000,
#   'NCAV Ratio': 1.1},
#  'RMR': {'Name': 'The RMR Group Inc.',
#   'Market Cap': 789630347,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Real Estate - Services',
#   'Has Dividends or Buybacks': 1.8,
#   '5Y average yield > 10%': 13.94,
#   '5Y average': 110088200.0,
#   'NCAV': 134648000,
#   'NCAV Ratio': 5.9},
#  'ITOS': {'Name': 'iTeos Therapeutics, Inc.',
#   'Market Cap': 383478900,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Market',
#   'Industry': 'Biotechnology',
#   'Has Dividends or Buybacks': -332000,
#   '5Y average yield > 10%': 12.71,
#   '5Y average': 48741600.0,
#   'NCAV': 538632000,
#   'NCAV Ratio': 0.7},
#  'HIMX': {'Name': 'Himax Technologies, Inc.',
#   'Market Cap': 974826000,
#   'HQ Location': 'TW',
#   'Exchange Location': 'NASDAQ Global Select',
#   'Industry': 'Semiconductors',
#   'Has Dividends or Buybacks': -9440593,
#   '5Y average yield > 10%': 13.11,
#   '5Y average': 127794398.2,
#   'NCAV': 397768144,
#   'NCAV Ratio': 2.5},
#  'GNE': {'Name': 'Genie Energy Ltd.',
#   'Market Cap': 431903282,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Regulated Electric',
#   'Has Dividends or Buybacks': -31700000,
#   '5Y average yield > 10%': 11.03,
#   '5Y average': 47656600.0,
#   'NCAV': 82899000,
#   'NCAV Ratio': 5.2},
#  'FF': {'Name': 'FutureFuel Corp.',
#   'Market Cap': 245949184,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Chemicals',
#   'Has Dividends or Buybacks': -3000,
#   '5Y average yield > 10%': 18.54,
#   '5Y average': 45589200.0,
#   'NCAV': 136851000,
#   'NCAV Ratio': 1.8},
#  'VNDA': {'Name': 'Vanda Pharmaceuticals Inc.',
#   'Market Cap': 272213366,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Market',
#   'Industry': 'Biotechnology',
#   'Has Dividends or Buybacks': 0.0,
#   '5Y average yield > 10%': 14.86,
#   '5Y average': 40458600.0,
#   'NCAV': 330325000,
#   'NCAV Ratio': 0.8},
#  'WILC': {'Name': 'G. Willi-Food International Ltd.',
#   'Market Cap': 149070250,
#   'HQ Location': 'IL',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Food Distribution',
#   'Has Dividends or Buybacks': -628000,
#   '5Y average yield > 10%': 14.37,
#   '5Y average': 21421000.0,
#   'NCAV': 431878000,
#   'NCAV Ratio': 0.3},
#  'PETS': {'Name': 'PetMed Express, Inc.',
#   'Market Cap': 75810576,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Select',
#   'Industry': 'Medical - Pharmaceuticals',
#   'Has Dividends or Buybacks': -11497000,
#   '5Y average yield > 10%': 29.88,
#   '5Y average': 22654200.0,
#   'NCAV': 18441000,
#   'NCAV Ratio': 4.1},
#  'MHH': {'Name': 'Mastech Digital, Inc.',
#   'Market Cap': 117993250,
#   'HQ Location': 'US',
#   'Exchange Location': 'American Stock Exchange',
#   'Industry': 'Staffing & Employment Services',
#   'Has Dividends or Buybacks': -631000,
#   '5Y average yield > 10%': 11.3,
#   '5Y average': 13336600.0,
#   'NCAV': 37148000,
#   'NCAV Ratio': 3.2},
#  'ASRT': {'Name': 'Assertio Holdings, Inc.',
#   'Market Cap': 112496008,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Drug Manufacturers - Specialty & Generic',
#   'Has Dividends or Buybacks': -10624000,
#   '5Y average yield > 10%': 27.77,
#   '5Y average': 31236400.0,
#   'NCAV': 30562000,
#   'NCAV Ratio': 3.7},
#  'SIEB': {'Name': 'Siebert Financial Corp.',
#   'Market Cap': 99499832,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Financial - Capital Markets',
#   'Has Dividends or Buybacks': -4274000,
#   '5Y average yield > 10%': 21.9,
#   '5Y average': 21792000.0,
#   'NCAV': 50292000,
#   'NCAV Ratio': 2.0},
#  'BRLT': {'Name': 'Brilliant Earth Group, Inc.',
#   'Market Cap': 126936265,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Market',
#   'Industry': 'Luxury Goods',
#   'Has Dividends or Buybacks': -14025000,
#   '5Y average yield > 10%': 13.57,
#   '5Y average': 17230400.0,
#   'NCAV': 31966000,
#   'NCAV Ratio': 4.0},
#  'WHG': {'Name': 'Westwood Holdings Group, Inc.',
#   'Market Cap': 132147322,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Financial - Capital Markets',
#   'Has Dividends or Buybacks': -27784000,
#   '5Y average yield > 10%': 16.22,
#   '5Y average': 21427800.0,
#   'NCAV': 37001000,
#   'NCAV Ratio': 3.6},
#  'SAMG': {'Name': 'Silvercrest Asset Management Group Inc.',
#   'Market Cap': 164119806,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Market',
#   'Industry': 'Asset Management',
#   'Has Dividends or Buybacks': -15000000,
#   '5Y average yield > 10%': 15.12,
#   '5Y average': 24815400.0,
#   'NCAV': 8185000,
#   'NCAV Ratio': 20.1},
#  'HNNA': {'Name': 'Hennessy Advisors, Inc.',
#   'Market Cap': 75351591,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Market',
#   'Industry': 'Asset Management',
#   'Has Dividends or Buybacks': -9087000,
#   '5Y average yield > 10%': 13.31,
#   '5Y average': 10028800.0,
#   'NCAV': 6300000,
#   'NCAV Ratio': 12.0},
#  'USIO': {'Name': 'Usio, Inc.',
#   'Market Cap': 38579433,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Market',
#   'Industry': 'Information Technology Services',
#   'Has Dividends or Buybacks': -2392442,
#   '5Y average yield > 10%': 13.38,
#   '5Y average': 5160619.0,
#   'NCAV': 6941039,
#   'NCAV Ratio': 5.6},
#  'GROW': {'Name': 'U.S. Global Investors, Inc.',
#   'Market Cap': 35159250,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Asset Management - Global',
#   'Has Dividends or Buybacks': -4246000,
#   '5Y average yield > 10%': 10.49,
#   '5Y average': 3688200.0,
#   'NCAV': 37360000,
#   'NCAV Ratio': 0.9},
#  'NCSM': {'Name': 'NCS Multistage Holdings, Inc.',
#   'Market Cap': 48401831,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Oil & Gas Equipment & Services',
#   'Has Dividends or Buybacks': -1339000,
#   '5Y average yield > 10%': 22.86,
#   '5Y average': 11063400.0,
#   'NCAV': 61520000,
#   'NCAV Ratio': 0.8},
#  'VCIG': {'Name': 'VCI Global Limited',
#   'Market Cap': 13593634,
#   'HQ Location': 'MY',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Consulting Services',
#   'Has Dividends or Buybacks': 0.01,
#   '5Y average yield > 10%': 46.25,
#   '5Y average': 6287278.6,
#   'NCAV': 23887333,
#   'NCAV Ratio': 0.6},
#  'VHC': {'Name': 'VirnetX Holding Corp',
#   'Market Cap': 26258948,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange',
#   'Industry': 'Software - Infrastructure',
#   'Has Dividends or Buybacks': -737000,
#   '5Y average yield > 10%': 131.63,
#   '5Y average': 34564000.0,
#   'NCAV': 37069000,
#   'NCAV Ratio': 0.7},
#  'NTWK': {'Name': 'NetSol Technologies, Inc.',
#   'Market Cap': 31991586,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Software - Application',
#   'Has Dividends or Buybacks': -3727308,
#   '5Y average yield > 10%': 11.75,
#   '5Y average': 3759624.6,
#   'NCAV': 22360760,
#   'NCAV Ratio': 1.4},
#  'CTNT': {'Name': 'Cheetah Net Supply Chain Service Inc.',
#   'Market Cap': 8358768,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Auto - Dealerships',
#   'Has Dividends or Buybacks': 0.0,
#   '5Y average yield > 10%': 15.53,
#   '5Y average': 1298284.6,
#   'NCAV': 11159631,
#   'NCAV Ratio': 0.7},
#  'SGE': {'Name': 'Strong Global Entertainment, Inc.',
#   'Market Cap': 12273342,
#   'HQ Location': 'US',
#   'Exchange Location': 'American Stock Exchange',
#   'Industry': 'Computer Hardware',
#   'Has Dividends or Buybacks': 0.0,
#   '5Y average yield > 10%': 17.11,
#   '5Y average': 2100200.0,
#   'NCAV': 5170000,
#   'NCAV Ratio': 2.4},
#  'MNDO': {'Name': 'MIND C.T.I. Ltd',
#   'Market Cap': 39562208,
#   'HQ Location': 'IL',
#   'Exchange Location': 'NASDAQ Global Market',
#   'Industry': 'Software - Application',
#   'Has Dividends or Buybacks': 0.24,
#   '5Y average yield > 10%': 14.33,
#   '5Y average': 5668000.0,
#   'NCAV': 10727000,
#   'NCAV Ratio': 3.7},
#  'CLRO': {'Name': 'ClearOne, Inc.',
#   'Market Cap': 14621151,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Communication Equipment',
#   'Has Dividends or Buybacks': 0.5,
#   '5Y average yield > 10%': 24.69,
#   '5Y average': 3610200.0,
#   'NCAV': 20113000,
#   'NCAV Ratio': 0.7},
#  'CODX': {'Name': 'Co-Diagnostics, Inc.',
#   'Market Cap': 39250530,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Medical - Devices',
#   'Has Dividends or Buybacks': -15575795,
#   '5Y average yield > 10%': 22.35,
#   '5Y average': 8771703.2,
#   'NCAV': 39915426,
#   'NCAV Ratio': 1.0},
#  'STCN': {'Name': 'Steel Connect, Inc.',
#   'Market Cap': 68847859,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Advertising Agencies',
#   'Has Dividends or Buybacks': 0.0,
#   '5Y average yield > 10%': 27.92,
#   '5Y average': 19220400.0,
#   'NCAV': 215301000,
#   'NCAV Ratio': 0.3},
#  'NICK': {'Name': 'Nicholas Financial, Inc.',
#   'Market Cap': 45187000,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Global Select',
#   'Industry': 'Financial - Credit Services',
#   'Has Dividends or Buybacks': -6335000,
#   '5Y average yield > 10%': 11.56,
#   '5Y average': 5222200.0,
#   'NCAV': 10591000,
#   'NCAV Ratio': 4.3},
#  'TAIT': {'Name': 'Taitron Components Incorporated',
#   'Market Cap': 17521631,
#   'HQ Location': 'US',
#   'Exchange Location': 'NASDAQ Capital Market',
#   'Industry': 'Technology Distributors',
#   'Has Dividends or Buybacks': -248000,
#   '5Y average yield > 10%': 11.23,
#   '5Y average': 1967800.0,
#   'NCAV': 11825000,
#   'NCAV Ratio': 1.5},
#  'GSG': {'Name': 'iShares S&P GSCI Commodity-Indexed Trust',
#   'Market Cap': 1317302895,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange Arca',
#   'Industry': 'Asset Management',
#   'Has Dividends or Buybacks': -2633972342,
#   '5Y average yield > 10%': 13.9,
#   '5Y average': 183162865.8,
#   'NCAV': 1063389475,
#   'NCAV Ratio': 1.2},
#  'HF': {'Name': 'DGA Absolute Return ETF',
#   'Market Cap': 907716433,
#   'HQ Location': None,
#   'Exchange Location': 'New York Stock Exchange Arca',
#   'Industry': None,
#   'Has Dividends or Buybacks': -31739000,
#   '5Y average yield > 10%': 11.11,
#   '5Y average': 100854800.0,
#   'NCAV': 95178000,
#   'NCAV Ratio': 9.5},
#  'DBC': {'Name': 'Invesco DB Commodity Index Tracking Fund',
#   'Market Cap': 2486447955,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange Arca',
#   'Industry': 'Asset Management',
#   'Has Dividends or Buybacks': 1.08926,
#   '5Y average yield > 10%': 11.29,
#   '5Y average': 280738748.4,
#   'NCAV': 694869032,
#   'NCAV Ratio': 3.6},
#  'DBE': {'Name': 'Invesco DB Energy Fund',
#   'Market Cap': 122635325,
#   'HQ Location': 'US',
#   'Exchange Location': 'New York Stock Exchange Arca',
#   'Industry': 'Asset Management',
#   'Has Dividends or Buybacks': -514119938,
#   '5Y average yield > 10%': 12.9,
#   '5Y average': 15816081.2,
#   'NCAV': 35236896,
#   'NCAV Ratio': 3.5}}

# %%
len(v)
# Out:
# 355
