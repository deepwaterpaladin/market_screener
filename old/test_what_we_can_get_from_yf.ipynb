# %% [markdown]
# ### Using yfinance
# 1. [ X ] check each ticker for divendeds `has_dividends`
# 1. [ X ] filter out non-dividened stocks `has_dividends` > 0
# 1. [ X ] check each ticker (out of filtered list) for Positive TTM Free-cashflow `get_free_cashflow`
# 1. [ X ] filter out stocks with negative TTM Free-cashflow `get_free_cashflow` > 0
# 1. [ X ] check each ticker (out of filtered list) for Market Cap <= NCAV `calculate_ncav`
# 1. [ X ] filter out stocks without Market Cap <= NCAV `calculate_ncav` >= market cap
# 1. [ X ] check each ticker (out of filtered list) for net-debt `get_net_debt`
# 1. [ X ] filter out stocks without zero or negative net-debt `get_net_debt` <= 0
# 1. [ ] check tickers HQ location
# 1. [ ] filter out non-whitelisted countries
#
# ### Remaining Calculations
# 1. [ ] Average 5Y annual Free Cash Flow yield at 10% or more
# 1. [ ] Get tickers full company name

# %%
import yfinance as yf
import pandas as pd
import json
from datetime import datetime
import os
from dotenv import load_dotenv

load_dotenv()
pd.set_option('display.float_format', lambda x: '%.3f' % x)

def read_json_file(file_path) ->list[str]:
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

def write_json_file(data, file_path):
    with open(file_path, 'w') as file:
        json.dump(data, file, indent=2)

def has_dividends(ticker: yf.Ticker) -> bool:
    return ticker.dividends.sum() > 0

def get_net_debt(ticker: yf.Ticker)->int:
    return ticker.quarterly_balance_sheet.loc['Net Debt'][0]

def get_total_liabilities(ticker: yf.Ticker)->int:
    try:
        return ticker.quarterly_balance_sheet.loc['Current Liabilities'][0]
    except:
        return -1

def get_total_debt(ticker: yf.Ticker)->int:
    try:
        return ticker.info['totalDebt']
    except:
        try:
            return ticker.quarterly_balance_sheet.loc["Total Debt"][0]
        except KeyError as k:
            return -1

def get_current_assets(ticker: yf.Ticker)->int:
    return ticker.quarterly_balance_sheet.loc['Total Assets'][0]

def get_free_cashflow(ticker: yf.Ticker)->int:
    return ticker.quarterly_cashflow.loc['Free Cash Flow'][0]

def get_net_debt(ticker: yf.Ticker) -> int:
    return ticker.quarterly_balance_sheet.loc['Net Debt'][0]

def calculate_ncav(ticker: yf.Ticker):
    '''
    Attempts two methods of calculating NCAV from yFinance API. If niether method works, returns -1. This would ensure the ticker would be removed from consideration.
    (1) uses `get_total_liabilities()` & `get_current_assets()` [both from `yf.Ticker.quarterly_balance_sheet` dataframe].
    (2) uses `get_total_debt()` & `get_current_assets()` [former uses `yf.Ticker().info`; ladder uses `yf.Ticker().quarterly_balance_sheet` dataframe].
    TODO: reduce api calls to one.
    TODO: check that `get_total_liabilities` == `get_total_debt`.
    TODO: determine better method for innermost Exception handling.
    '''
    try:
        total_liabilities = ticker.quarterly_balance_sheet.loc['Total Liabilities Net Minority Interest'][0]
        current_assets = ticker.quarterly_balance_sheet.loc['Current Assets'][0]
        return current_assets - total_liabilities
    except KeyError or TypeError as k:
        return -1 # for now
        # try:
        #     debt = get_total_debt(ticker)
        #     current_assets = get_current_assets(ticker)
        #     return current_assets - debt
        # except KeyError or TypeError as ke:
        #     return -1 # could use another function to find values elsewhere.
            
def get_country(ticker: yf.Ticker) -> str:
    return ticker.info['country']

def is_whitelist_nation(country: str) -> bool:
    countries = ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic',
    'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
    'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands',
    'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
    'USA', 'United States', 'Canada', 'United Kingdom', 'UK', 'Japan', 'Australia']
    return country in countries

def convert_cik_list(file_path: str) -> dict:
    result_dict = {}
    
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split(':')
            if len(parts) == 2:
                ticker = parts[0].strip().upper()
                value = int(parts[1].strip())
                result_dict[ticker] = value
    
    return result_dict

def create_dataframe(data_dict: dict) -> pd.DataFrame:
    df = pd.DataFrame.from_dict(data_dict, orient='index')
    return df

def driver(data_arr: list[str], debug: bool = False) -> dict[str: dict]:
    start_time = datetime.now()
    ret_dict = {i:{"Has Dividends": bool, "Net Debt": bool, "Positive Free Cashflow": bool, "Market Cap <= NCAV": bool, "HQ Country": str} for i in data_arr}
    removal_matrix = [[],[],[],[], []]
    if debug:
        print(f"{len(ret_dict)} Tickers to be screened.")
    
    for key, val in ret_dict.items(): # check "Has Dividends"
        try:
            ticker = yf.Ticker(key)
            ticker_has_dividends = has_dividends(ticker)
            if ticker_has_dividends:
               val["Has Dividends"] = True
            else:
                removal_matrix[0].append(key)
        except KeyError or TypeError as k:
            removal_matrix[0].append(key) 
    
    print(f"Time to check dividends: {datetime.now() - start_time}") # average time to check dividends: 0:20:24 – 0:21:55 (hh:mm:ss).

    for i in removal_matrix[0]: # remove Ticker symbols that don't pay dividends
        ret_dict.pop(i)

    if debug:
        print(f"{len(ret_dict)} Tickers to be screened.")
    start_market_cap = datetime.now()
    
    for key, val in ret_dict.items(): # check "Market Cap <= NCAV"
        try:
            ticker = yf.Ticker(key)
            market_cap = ticker.info['marketCap']
            is_positive_ncav = market_cap <= calculate_ncav(ticker)
            if is_positive_ncav:
                val["Market Cap <= NCAV"] = True
            else:
                removal_matrix[1].append(key) # remove tickers with Market Cap > NCAV
        except KeyError or ValueError as k:
            removal_matrix[1].append(key) 
    print(f"Time to check Market Cap <= NCAV: {datetime.now() - start_market_cap}")

    for i in removal_matrix[1]: # remove tickers with Market Cap > NCAV
        ret_dict.pop(i)

    if debug:
        print(f"{len(ret_dict)} Tickers to be screened.")
    start_ttm = datetime.now()
    
    for key, val in ret_dict.items(): # check "Positive Free Cashflow"
        try:
            ticker = yf.Ticker(key)
            has_positive_ttm = get_free_cashflow(ticker) > 0
            if has_positive_ttm:
                val["Positive Free Cashflow"] = True
            else:
                removal_matrix[2].append(key) 
        except KeyError as k:
            removal_matrix[2].append(key) 
    print(f"Time to check Positive Free Cashflow: {datetime.now() - start_ttm}")
    
    for i in removal_matrix[2]: # remove tickers with negative TTM (i.e., Positive Free Cashflow)
        ret_dict.pop(i)

    if debug:
        print(f"{len(ret_dict)} Tickers to be screened.")
    start_net_debt = datetime.now()

    for key, val in ret_dict.items(): # check "Net Debt".
        try:
            ticker = yf.Ticker(key)
            has_net_debt = get_net_debt(ticker) > 0
            if has_net_debt:
                val["Net Debt"] = True
            else:
                removal_matrix[3].append(key)
        except:
            try:
                has_net_debt = get_total_debt(ticker)
                if has_net_debt:
                    val["Net Debt"] = True
                else:
                    removal_matrix[3].append(key)
            except:
                removal_matrix[3].append(key)
    print(f"Time to check Net Debt: {datetime.now() - start_net_debt}")

    for i in removal_matrix[3]: # remove tickers without Positive "Net Debt".
        ret_dict.pop(i)
    adding_hq = datetime.now()
    
    for key, val in ret_dict.items(): # assuming all tickers have a country.
        ticker = yf.Ticker(key)
        country = get_country(ticker)
        if is_whitelist_nation(country): # remove non-whitelisted tickers
            val["HQ Country"] = country
        else:
            removal_matrix[4] = key
    print(f"Time to check HQs': {datetime.now() - adding_hq}")

    for i in removal_matrix[4]:
        if len(i) != 1:
            ret_dict.pop(i)

    cik_dict = convert_cik_list('./cik.txt')
    for key, val in ret_dict.items():
        val["CIK"] = cik_dict.get(key, "NONE")
    
    print(f"{len(ret_dict)} tickers remaining. {len(removal_matrix[0])+len(removal_matrix[1])+len(removal_matrix[2])+len(removal_matrix[3])} stocks screened out")
    print(f"tickers removed: {removal_matrix}")
    
    return ret_dict


data = read_json_file('./tickers.json')
data2 = read_json_file('./new_tickers.json')
cik_dict = convert_cik_list('./cik.txt')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()

# %%
market_caps = [0] * len(data)
tickers_to_remove = []

for i in range(len(data)-1):
    try:
        t = yf.Ticker(data[i])
        market_caps[i] = t.info['marketCap']
    except KeyError as k:
        print(f"Key error occurred when looking for market cap for ticker: {data[i]}")
        tickers_to_remove.append(data[i])

# %%
new_data = [i for i in data if i not in tickers_to_remove]
len(new_data)

with open("new_tickers.json", 'w') as file:
    json.dump(data, file, indent=2)

# %%
d = {i:bool for i in data2}
missing = []

for i in data2:
    try:
        t = yf.Ticker(i)
        ncav = calculate_ncav(t)
        market_cap = t.info['marketCap']
        d[i] = market_cap <= ncav
    except KeyError as ke:
        missing.append(i)

# %%
dd = {i:bool for i in missing}
still_missing = []
for i in missing:
    try:
        t = yf.Ticker(i)
        debt = get_total_debt(t)
        current_assets = get_current_assets(t)
        market_cap = t.info['marketCap']
        dd[i] = market_cap <= (current_assets - debt)
    except KeyError as k:
        still_missing.append(i)
len(still_missing)

# %%
fin = [i for i in data2 if i not in still_missing]
has_dividends_dict = {i:bool for i in fin}
for i in fin:
    try:
        t = yf.Ticker(i)
        has_dividends_dict[i] = has_dividends(t)
    except KeyError as k:
        print(f'error with {i}')

# %%
no_ttm = []
ttm = {i:0 for i in data2}

for i in data2:
    try:
        t = yf.Ticker(i)
        ttm[i] = get_free_cashflow(t)
    except KeyError as k:
        print(f'error with {i}')
        no_ttm.append(i)
print(len(no_ttm))
# Out:
# error with SMFG
# error with DB
# error with HGAS
# error with IGIC
# error with EVAX
# error with LILM
# error with SAI
# error with APLM
# error with TYG
# error with CANF
# error with DRD
# error with IREN
# error with PRZO
# error with PHG
# error with WAVE
# error with AVAL
# error with ING
# error with WDS
# error with IMOS
# error with GRFS
# error with BLTE
# error with IHG
# error with TURN
# error with GFI
# error with BAP
# error with CREV
# error with VCIG
# error with BTDR
# error with SNT
# error with CACO
# error with RIO
# error with IVA
# error with NCNC
# error with CIB
# error with WRNT
# error with ORAN
# error with MOB
# error with SBSW
# error with CAMT
# error with SNN
# error with MTEK
# error with MTR
# error with ADD
# error with NLSP
# error with VOC
# error with ARVL
# error with VEON
# error with MSDL
# error with SHLT
# error with ARQQ
# error with LGHL
# error with MFG
# error with NVNI
# error with NBTX
# error with GNFT
# error with DEC
# error with GYRO
# error with OKYO
# error with APM
# error with SKIL
# error with ALAR
# error with CZOO
# error with CYTO
# error with BUD
# error with NGNE
# error with OMH
# error with PMEC
# error with DXR
# error with GDTC
# error with SOGP
# error with CDLR
# error with BCS
# error with BHP
# error with MUFG
# error with LYT
# error with BDRX
# error with IMRN
# error with DEO
# error with DSX
# error with RTO
# error with SJT
# error with MARPS
# error with CYD
# error with BREA
# error with FRGT
# error with DCFC
# error with NWG
# error with SLGL
# error with TOPS
# error with SVMH
# error with SSL
# error with JFBR
# error with RELX
# error with PRT
# error with PUK
# error with SGHC
# error with WALD
# error with BYSI
# error with PNST
# error with AISP
# error with SVRE
# error with IPHA
# error with TLSA
# error with CLBR
# error with BANL
# error with NRSN
# error with BNZI
# error with RDCM
# error with GRVY
# error with CDRO
# error with JCSE
# error with WLDS
# error with BOWN
# error with MRM
# error with GRRR
# error with GIGM
# error with INDO
# error with IROH
# error with TURB
# error with ASA
# error with ARGX
# error with CET
# error with GV
# error with MRT
# error with HWH
# error with NAMS
# error with ALLG
# error with STLA
# error with CX
# error with HLN
# error with WPP
# error with ANGH
# error with BON
# error with FTEL
# error with TKLF
# error with CAPT
# error with GVH
# error with HMY
# error with DTCK
# error with ASLN
# error with OPT
# error with NGG
# error with MWG
# error with SOAR
# error with FORTY
# error with VIAO
# error with HUBC
# error with SPRC
# error with ELWS
# error with MDGS
# error with LND
# error with VOD
# error with ADSE
# error with GNTA
# error with SYT
# error with PXDT
# error with GFAI
# error with AKTX
# error with SPPL
# error with AFJK
# error with BRSH
# error with PSO
# error with FMX
# error with BAYA
# error with LGCB
# error with SMX
# error with EEIQ
# error with CLDI
# error with CRT
# error with NTBL
# error with CCEP
# error with AKAN
# error with PHXM
# error with OPTX
# error with HSBC
# error with DRTS
# error with VSTE
# error with XTLB
# error with LAES
# error with CRH
# error with MYNA
# error with WBX
# error with GGAL
# error with UL
# error with PBT
# error with BROG
# error with WBUY
# error with PERF
# error with SIFY
# error with MREO
# error with VVPR
# error with ABVX
# error with AFRI
# error with LYG
# error with KRRO
# error with SDHC
# error with SPCB
# error with PVL
# error with BANX
# error with SILC
# error with HOVR
# error with IINN
# error with ARBB
# error with SYNX
# error with GLOB
# error with BOSC
# error with WKEY
# error with STBX
# error with BMR
# error with CPBI
# error with LRE
# error with SAN
# error with NWTN
# error with VRAX
# error with KZIA
# error with BPTS
# error with BTI
# error with IBN
# error with CNTG
# error with BGI
# error with ECC
# error with HDB
# error with YALA
# error with SNY
# error with FRES
# error with PRTC
# error with MDRX
# error with QETA
# error with TCBP
# error with CGEN
# error with PYPD
# error with LITM
# error with SATL
# 233

# %%
partially_screened = driver(data2, debug= True)
# Out:
# 5250 Tickers to be screened.
# Time to check dividends: 0:22:53.417085
# 2312 Tickers to be screened.
# Time to check Market Cap <= NCAV: 0:18:24.658967
# 31 Tickers to be screened.
# Time to check Positive Free Cashflow: 0:00:06.811184
# 12 Tickers to be screened.
# Time to check Net Debt: 0:00:04.842178
# Time to check HQs': 0:00:00.909184
# 11 tickers remaining. 5239 stocks screened out
# tickers removed: [['CLBT', 'AZUL', 'THRD', 'GBIO', 'SMFG', 'PFIE', 'LGMK', 'ORGS', 'CERS', 'XLO', 'AMWL', 'LBRDK', 'TBBK', 'DRRX', 'DNLI', 'FTRE', 'GTLS', 'PHUN', 'SPT', 'LTRY', 'PRLD', 'PPIH', 'BROS', 'MGAM', 'VISL', 'CPSS', 'ALLR', 'IPX', 'AMBI', 'NR', 'BKYI', 'FLL', 'THAR', 'ONTX', 'IDEX', 'CDTX', 'BCAL', 'NTLA', 'SGMO', 'MRKR', 'CLH', 'WVVI', 'EFOI', 'ARDX', 'ALT', 'HGAS', 'ANTX', 'SENS', 'RRGB', 'EVAX', 'AMPE', 'AVXL', 'LILM', 'VINO', 'OCTO', 'MTTR', 'SAI', 'MXCT', 'BDTX', 'SNCY', 'ESLA', 'APLM', 'SMMT', 'CMPS', 'DLO', 'TGL', 'NU', 'HOOD', 'NCDL', 'SNES', 'CDAY', 'EGAN', 'MYTE', 'ADOC', 'FLNC', 'NAII', 'CRMD', 'DOMH', 'TBLT', 'STKH', 'AUST', 'CANF', 'FWBI', 'MDXH', 'INOD', 'ADTH', 'RBT', 'CLOV', 'OWLT', 'CNDB', 'XPDB', 'DXCM', 'IOVA', 'KNSA', 'CXM', 'FET', 'LOPE', 'BBAI', 'DIBS', 'NET', 'TWKS', 'ADPT', 'GLBE', 'VS', 'UBER', 'NWPX', 'TLGY', 'POET', 'IREN', 'PTN', 'SRBK', 'RVSN', 'MRIN', 'PRAX', 'BTMD', 'ATAI', 'ACEL', 'RENT', 'LSAK', 'MP', 'DSGN', 'CHEA', 'IVAC', 'UUUU', 'LIQT', 'UNFI', 'PAY', 'FHLT', 'GPCR', 'PRZO', 'VZIO', 'ELAN', 'SN
', 'CTKB', 'AIM', 'WRNT', 'IESC', 'HUT', 'ONON', 'MCAG', 'OTLK', 'PWUP', 'PI', 'FLWS', 'WEST', 'EDAP', 'RSVR', 'SGBX', 'NPWR', 'NTRA', 'MOB', 'SYRS', 'PEPL', 'RCM', 'OFIX', 'CYRX', 'CACC', 'DYNT', 'CTLP', 'THM', 'CIEN', 'PROF', 'LMND', 'ACGL', 'ARVN', 'ACLS', 'BIGC', 'ANEB', 'QLYS', 'SGN', 'MDBH', 'MTEK', 'RMNI', 'TWLO', 'CHKP', 'GMFI', 'KPLT', 'OPTT', 'ARMP', 'ARTL', 'SMCI', 'LVTX', 'WRLD', 'ADD', 'CUBI', 'UGRO', 'ICCC', 'PCT', 'STRL', 'RACY', 'PYCR', 'YMAB', 'GATO', 'CEAD', 'THRY', 'LIFW', 'XPON', 'GRNQ', 'GENE', 'NLSP', 'UONEK', 'LCID', 'XENE', 'ALIM', 'AACI', 'ITRM', 'BLND', 'IPGP', 'NG', 'LUNG', 'HIMS', 'ASTS', 'CEVA', 'BEAM', 'PSQH', 'MXC', 'KIND', 'ARVL', 'MYRG', 'CRKN', 'MNTX', 'ORLA', 'MSDL', 'MCAC', 'BOXL', 'KTCC', 'FEMY', 'HYAC', 'WIX', 'MCW', 'AERT', 'SCWO', 'GROM', 'BARK', 'NOVT', 'THR', 'SHLT', 'NRBO', 'AXDX', 'AGAE', 'SRI', 'BLUA', 'HYMC', 'MRVI', 'CCCS', 'PTCT', 'SLQT', 'ARQQ', 'SLAC', 'OLLI', 'DSGX', 'ACET', 'VLCN', 'IMMP', 'LGHL', 'SIBN', 'ELPC', 'ACAC', 'HOUR', 'VIVK', 'ENVA', 'TDC', 'LPSN', 'MTEM', 'SWIM', 'MFG', 'LSTA', 'NVFY', 'NCRA', 'PPYA', 'MLSS', 'SMTI', 'LVWR', 'AVGR', 'PMVP', 'NVNI', 'GPAK', 'DMK', 'SHOP', 'WBD', 'NBTX', 'VRM', 'RVNC', 'ICCT', 'I ...

# %%
df = create_dataframe(partially_screened)
df
# Out:
#       Has Dividends  Net Debt  Positive Free Cashflow  Market Cap <= NCAV  \
# MTBL           True      True                    True                True
# LGL            True      True                    True                True
# FBRT           True      True                    True                True
# EQC            True      True                    True                True
# LDWY           True      True                    True                True
# STCN           True      True                    True                True
# JRSH           True      True                    True                True
# IOR            True      True                    True                True
# ACTG           True      True                    True                True
# HURC           True      True                    True                True
# EDUC           True      True                    True                True
#
#          HQ Country      CIK
# MTBL  United States     NONE
# LGL   United States    61004
# FBRT  United States  1562528
# EQC   United States   803649
# LDWY  United States     NONE
# STCN  United States   914712
# JRSH  United States  1696558
# IOR   United States   949961
# ACTG  United States   934549
# HURC  United States   315374
# EDUC  United States    31667

# %%
df.to_excel("full.xlsx", index=True)

# %%
ind = df.index.to_list()
partially_screened_sum = len(ind)
partially_screened_sum
partially_screened_also_in_cik = [i for i in ind if i in cik_dict.keys()]
len(partially_screened_also_in_cik)
# Out:
# 9

# %% [markdown]
# ## try to get FCF from EDGAR docs

# %%
ttms = [1123000,472000,72000]
average = sum(ttms)/3
average_three_year_fcf = round(average*1000, 2)
market_capitalization = 4693000000
(average_three_year_fcf / market_capitalization) * 100

# %%
# Calculate Score
# cash + average_three_year_fcf 

market_capitalization/(yf.Ticker("FNB").get_cashflow().loc['EndCashPosition'][0] + average_three_year_fcf)

# %%
yf.Ticker("FNB").quarterly_balance_sheet
# Out:
#                                                   2023-09-30      2023-06-30  \
# Treasury Shares Number                          16110462.000    16114836.000
# Preferred Shares Number                          4435080.000     4435080.000
# Ordinary Shares Number                         358828542.000   358820568.000
# Share Issued                                   374939004.000   374935404.000
# Net Debt                                      2108000000.000  2391000000.000
# Total Debt                                    3745000000.000  4095000000.000
# Tangible Book Value                           3236000000.000  3155000000.000
# Invested Capital                              9532000000.000  9806000000.000
# Net Tangible Assets                           3343000000.000  3262000000.000
# Common Stock Equity                           5787000000.000  5711000000.000
# Preferred Stock Equity                         107000000.000   107000000.000
# Total Capitalization                          7974000000.000  7913000000.000
# Total Equity Gross Minority Interest          5894000000.000  5818000000.000
# Stockholders Equity                           5894000000.000  5818000000.000
# Gains Losses Not Affecting Retained Earnings  -382000000.000  -355000000.000
# Treasury Stock                                 188000000.000   188000000.000
# Retained Earnings                             1664000000.000  1564000000.000
# Additional Paid In Capital                    4689000000.000  4686000000.000
# Capital Stock                                  111000000.000   111000000.000
# Common Stock                                     4000000.000     4000000.000
# Preferred Stock                                107000000.000   107000000.000
# Total Liabilities Net Minority Interest      39602000000.000 38960000000.000
# Long Term Debt And Capital Lease Obligation   2080000000.000  2095000000.000
# Long Term Debt                                2080000000.000  2095000000.000
# Current Debt And Capital Lease Obligation     1665000000.000  2000000000.000
# Current Debt                                  1665000000.000  2000000000.000
# Other Current Borrowings                      1665000000.000  2000000000.000
# Total Assets                                 45496000000.000 44778000000.000
# Investments And Advances                      7067000000.000  7165000000.000
# Held To Maturity Securities                   3922000000.000  3988000000.000
# Goodwill And Other Intangible Assets          2551000000.000  2556000000.000
# Other Intangible Assets                         74000000.000    79000000.000
# Goodwill                                      2477000000.000  2477000000.000
# Net PPE                                        460000000.000   465000000.000
# Accumulated Depreciation                                 NaN             NaN
# Gross PPE                                                NaN             NaN
# Other Properties                                         NaN             NaN
# Machinery Furniture Equipment                            NaN             NaN
# Buildings And Improvements                               NaN             NaN
# Land And Improvements                                    NaN             NaN
# Receivables                                    562000000.000   618000000.000
# Other Receivables                              562000000.000   618000000.000
# Other Short Term Investments                  3145000000.000  3177000000.000
# Cash And Cash Equivalents                     1637000000.000  1704000000.000
# Cash Financial                                 409000000.000   449000000.000
#
#                                                   2023-03-31      2022-12-31
# Treasury Shares Number                          14575547.000    14437135.000
# Preferred Shares Number                          4435080.000     4435080.000
# Ordinary Shares Number                         360359857.000   360470110.000
# Share Issued                                   374935404.000   374907245.000
# Net Debt                                      1294000000.000   474000000.000
# Total Debt                                    3017000000.000  2148000000.000
# Tangible Book Value                           3120000000.000  2980000000.000
# Invested Capital                              8698000000.000  7694000000.000
# Net Tangible Assets                           3227000000.000  3087000000.000
# Common Stock Equity                           5681000000.000  5546000000.000
# Preferred Stock Equity                         107000000.000   107000000.000
# Total Capitalization                          7205000000.000  6871000000.000
# Total Equity Gross Minority Interest          5788000000.000  5653000000.000
# Stockholders Equity                           5788000000.000  5653000000.000
# Gains Losses Not Affecting Retained Earnings  -315000000.000  -357000000.000
# Treasury Stock                                 172000000.000   167000000.000
# Retained Earnings                             1471000000.000  1370000000.000
# Additional Paid In Capital                    4693000000.000  4696000000.000
# Capital Stock                                  111000000.000   111000000.000
# Common Stock                                     4000000.000     4000000.000
# Preferred Stock                                107000000.000   107000000.000
# Total Liabilities Net Minority Interest      38358000000.000 38072000000.000
# Long Term Debt And Capital Lease Obligation   1417000000.000  1218000000.000
# Long Term Debt                                1417000000.000  1218000000.000
# Current Debt And Capital Lease Obligation     1600000000.000   930000000.000
# Current Debt                                  1600000000.000   930000000.000
# Other Current Borrowings                      1600000000.000   930000000.000
# Total Assets                                 44146000000.000 43725000000.000
# Investments And Advances                      7274000000.000  7362000000.000
# Held To Maturity Securities                   4073000000.000  4087000000.000
# Goodwill And Other Intangible Assets          2561000000.000  2566000000.000
# Other Intangible Assets                         84000000.000    89000000.000
# Goodwill                                      2477000000.000  2477000000.000
# Net PPE                                        452000000.000   432000000.000
# Accumulated Depreciation                                 NaN  -335000000.000
# Gross PPE                                                NaN   767000000.000
# Other Properties                                         NaN    23000000.000
# Machinery Furniture Equipment                            NaN   406000000.000
# Buildings And Improvements                               NaN   264000000.000
# Land And Improvements                                    NaN    74000000.000
# Receivables                                    562000000.000   505500000.000
# Other Receivables                              562000000.000   505500000.000
# Other Short Term Investments                  3201000000.000  3275000000.000
# Cash And Cash Equivalents                     1723000000.000  1674000000.000
# Cash Financial                                 445000000.000   443000000.000

# %%
data = read_json_file("./tickers_tradingview.json")
# Out:
# 24

# %%
tv = read_json_file('./tv_extract.json')

clean = {'Japan': '.T',
 'Canada': '.TO',
 'Austria': '.VI',
 'Belgium': '.BR',
 'Estonia': '.TL',
 'France': '.PA',
 'Germany': '.DE',
 'Greece': '.AT',
 'Hungary': '.BD',
 'Italy': '.MI',
 'Latvia': '.RG',
 'Lithuania': '.VS',
 'Netherlands': '.AS',
 'Poland': '.WS',
 'Portugal': '.LS',
 'Romania': '.RO',
 'Finland': '.HE',
 'Spain': '.MC',
 'Sweden': '.ST',
 'Switzerland': '.SW',
 'United Kingdom': '.L',
 'New Zealand': '.NZ',
 'Czech Republic': '.PR',
 'USA': ''}

for k, v in tv.items():
    tv[k] = [i.split(':')[1]+clean[k] for i in tv[k]]


all_data = [item for sublist in tv.values() for item in sublist]
driva = driver(all_data, debug= True)
# Out:
# 22657 Tickers to be screened.
# 9942.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 1869.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 9035.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 8228.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 2902.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3830.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 9359.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 9402.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 6076.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 9027.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3055.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3504.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 7488.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 1832.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 8190.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 9407.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 6797.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 8398.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 7533.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5993.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 9664.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 9085.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 7227.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 2551.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 1777.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3057.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 1892.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5356.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 9471.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5607.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3952.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3066.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 8560.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5979.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 8071.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 8554.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 6142.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 6295.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 2218.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 6111.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 8145.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3739.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 2058.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 1771.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 6655.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 9170.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5343.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 2974.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 7894.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 2467.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 8559.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 7076.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 7870.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 1738.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3419.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3775.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 7075.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5075.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3808.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3442.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5342.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 6025.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3849.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3346.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 4250.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 6439.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 4018.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3384.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3032.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3047.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 2172.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 3824.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 1734.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5836.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 6225.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5530.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 1553.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5039.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 5579.T: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# GIB.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# RCI.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# TPX.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# CCL.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# TOI.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# EMP.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# U.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# QBR.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# BBD.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# GTII.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ACO.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# TRUL.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# SGML.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# VRNO.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# LMN.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# FIH.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# NGEX.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# CL.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ARTG.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# HPS.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# TCL.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# EU.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# AFM.TO: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-06)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# LAS.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ISO.TO: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-06)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# SGD.TO: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-06)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# DHT.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# NFG.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ASE.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# CUP.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# GBU.TO: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-06)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# RML.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# AGF.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# WED.TO: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-06)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# RAY.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# TINY.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# LGN.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# RGD.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# GRZ.TO: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-06)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# AAWH.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# VZLA.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# GLAS.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# LA.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# CAD.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ABXX.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# CSW.TO: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-06)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# HIVE.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# LOU.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# AMRQ.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# AYR.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# SLI.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# CEI.TO: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-06)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# BRVO.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ODV.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# HFPC.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# VERS.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# PLTH.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# IBAT.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# JUSH.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# FUU.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# LI.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# MFG.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# RECO.TO: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# OSI.TO: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-06)
# ...
# SCP.L: No price data found, symbol may be delisted (1d 1925-03-03 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# Failed to get ticker 'UIGB.L' reason: HTTPSConnectionPool(host='guce.yahoo.com', port=443): Read timed out. (read timeout=30)
# UIGB.L: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# Failed to get ticker 'INV.L' reason: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# INV.L: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# Failed to get ticker 'WCCA.L' reason: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# WCCA.L: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# Failed to get ticker 'BRFI.L' reason: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# BRFI.L: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# 0MWO.L: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# EDMG.L: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# JAAV.L: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# BX: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# WM: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# RSG: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# WMB: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# QSR: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# BF: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# CCL: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# EPAM: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ALB: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# H: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# CPB: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# MRO: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ROKU: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# Failed to get ticker 'Z' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Max retries exceeded with url: /v8/finance/chart/Z?range=1d&interval=1d&crumb=B6LY1SM%2FUWG (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x124df65c0>: Failed to resolve 'query2.finance.yahoo.com' ([Errno 8] nodename nor servname provided, or not known)"))
# Z: No timezone found, symbol may be delisted
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# DAY: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ELF: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# LAD: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# AM: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ATI: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ACT: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# LGF: No price data found, symbol may be delisted (1d 1925-03-02 -> 2024-02-07)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/base.py:1960: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
    response = requests.get(url)
    return response.json()

def five_year_yield(ticker: str) -> float:
    return round((get_five_year_fcf_average(ticker) / get_profile(ticker)[0]['mktCap'])*100, 2)

# %%
driva
# Out:
# {'3254.T': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'Japan',
#   'CIK': 'NONE'},
#  '6804.T': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'Japan',
#   'CIK': 'NONE'},
#  '8084.T': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'Japan',
#   'CIK': 'NONE'},
#  '7229.T': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'Japan',
#   'CIK': 'NONE'},
#  '7266.T': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'Japan',
#   'CIK': 'NONE'},
#  '6393.T': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'Japan',
#   'CIK': 'NONE'},
#  'BUI.TO': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'Canada',
#   'CIK': 'NONE'},
#  'HWO.TO': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'Canada',
#   'CIK': 'NONE'},
#  'SFG1T.TL': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'Estonia',
#   'CIK': 'NONE'},
#  'IRC.MI': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'Italy',
#   'CIK': 'NONE'},
#  'BZ': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': str,
#   'CIK': 1842827},
#  'RLX': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': str,
#   'CIK': 1828365},
#  'FINV': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': str,
#   'CIK': 1691445},
#  'MOMO': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': str,
#   'CIK': 1610601},
#  'VINP': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': str,
#   'CIK': 1826286},
#  'ACTG': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'United States',
#   'CIK': 934549},
#  'YRD': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': str,
#   'CIK': 1631761},
#  'FANH': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': str,
#   'CIK': 1413855},
#  'HURC': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'United States',
#   'CIK': 315374},
#  'WILC': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': str,
#   'CIK': 1030997},
#  'CAAS': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': str,
#   'CIK': 1157762},
#  'STCN': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'United States',
#   'CIK': 914712},
#  'JRSH': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'United States',
#   'CIK': 1696558},
#  'MTBL': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'United States',
#   'CIK': 'NONE'},
#  'EDUC': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'United States',
#   'CIK': 31667},
#  'LDWY': {'Has Dividends': True,
#   'Net Debt': True,
#   'Positive Free Cashflow': True,
#   'Market Cap <= NCAV': True,
#   'HQ Country': 'United States',
#   'CIK': 'NONE'}}

# %%
drop = []
for k, v in driva.items():
    try:
        yie = five_year_yield(k)
        print(f'Five year average earnings yield for {k}: {yie}%')
    except:
        drop.append(k)
print(len(drop))
# Out:
# 26

# %%
{i:'' for i in tv.keys()}
# Out:
# {'Japan': '',
#  'Canada': '',
#  'Austria': '',
#  'Belgium': '',
#  'Estonia': '',
#  'France': '',
#  'Germany': '',
#  'Greece': '',
#  'Hungary': '',
#  'Italy': '',
#  'Latvia': '',
#  'Lithuania': '',
#  'Netherlands': '',
#  'Poland': '',
#  'Portugal': '',
#  'Romania': '',
#  'Finland': '',
#  'Spain': '',
#  'Sweden': '',
#  'Switzerland': '',
#  'United Kingdom': '',
#  'New Zealand': '',
#  'Russia': '',
#  'Czech Republic': '',
#  'USA': ''}
